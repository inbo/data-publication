# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
import sys
sys.path.append("../gbif_species_name_extraction/")
from gbif_species_name_extraction import extract_species_information, extract_gbif_species_names_info, extract_gbif_accepted_key, _escape_spaces

# %%
sys.path.append("../../mapping/")
from support_functions import pandas_df_to_markdown_table

# %%
import asyncio
import aiohttp
import requests

# %% [markdown]
# ## Recorder unique scientific names derived from the nameserver

# %% [markdown]
# I extracted all unique species names from recorder (NBN-data) to make an overview of the species (for all surveys). After matching with GBIF, we can make a mapping in between 'recommended names' as defined by recorder and the accepted_keys from GBIF. If we manage to make this mapping, we can later on make an easy selection in both directions GBIF <-> Recorder.

# %% [markdown]
# First of all, extract the Recorder unique species names, by querying the NBN-database. for which the Query is stored in `SQL_unique_names.sql`:

# %%
recorder_names = pd.read_csv("recorder_sql_unique_names_output.csv", delimiter='\t', dtype=object)

# %%
recorder_names.head()
# Out:
#   RECOMMENDED_TAXON_VERSION_KEY             scientificName  \
# 0              NHMSYS0000456996                   Caylusea
# 1              NHMSYS0000900079     Listrognathus mactator
# 2              NBNSYS0100004462  Paratanytarsus dissimilis
# 3              NHMSYS0000603228   Gymnodinium colymbeticum
# 4              NHMSYS0000875969                 Formicinae
#
#                          TAXON_GROUP_NAME
# 0                              bloemplant
# 1  insect - vliesvleugelige (Hymenoptera)
# 2          insect - vlieg & mug (Diptera)
# 3                                    wier
# 4  insect - vliesvleugelige (Hymenoptera)

# %%
len(recorder_names)
# Out:
# 144135

# %%
recorder_names[recorder_names['TAXON_GROUP_NAME'] == 'niet toegewezen']
# Out:
#        RECOMMENDED_TAXON_VERSION_KEY   scientificName TAXON_GROUP_NAME
# 6467                NHMSYS0001697203       Prokaryota  niet toegewezen
# 10559               NHMSYS0000841310       Arthropoda  niet toegewezen
# 37772               INBSYS0000012542    Procyon lotor  niet toegewezen
# 38067               NHMSYS0000841034      Lepidoptera  niet toegewezen
# 42688               NBNSYS0000160353   Lycopodiopsida  niet toegewezen
# 65550               NHMSYS0000842161         Protista  niet toegewezen
# 70145               NBNSYS0000172125        Bryophyta  niet toegewezen
# 79432               NHMSYS0000841378           Pisces  niet toegewezen
# 92240               NHMSYS0000841351          Insecta  niet toegewezen
# 101203              NHMSYS0001747258   Lycopodiophyta  niet toegewezen
# 102896              NHMSYS0000376165        Carnivora  niet toegewezen
# 103741              NBNSYS0000160581  Order uncertain  niet toegewezen
# 109623              NBNSYS0000159411        Arachnida  niet toegewezen
# 112874              NBNSYS0000160231          Insecta  niet toegewezen
# 124678              INBSYS0000012552      Procyonidae  niet toegewezen
# 125381              NBNSYS0000174484      Chelicerata  niet toegewezen
# 139314              NBNSYS0000175876   Incertae sedis  niet toegewezen
# 139341              INBSYS0000012554          Procyon  niet toegewezen

# %%
recorder_names['TAXON_GROUP_NAME'].unique()
# Out:
# array(['bloemplant', 'insect - vliesvleugelige (Hymenoptera)',
#        'insect - vlieg & mug (Diptera)', 'wier', 'diatomee',
#        'pseudoschorpioen (Pseudoscorpiones)', 'raderdiertje (Rotifera)',
#        'springstaart (Collembola)', 'insect - kever (Coleoptera)',
#        'levermos', 'foraminifeer', 'rondworm (Nematoda)', 'zwam',
#        'lintworm (Cestoda)', 'ringworm', 'amfibie', 'mollusk (Mollusca)',
#        'insect - nachtvlinder', 'bacterie', 'neteldier (=cnidarian)',
#        'insect - vlo (Siphonaptera)', 'schaaldier', 'fungoide',
#        'insect - trips (Thysanoptera)', 'buikhaarworm (Gastrotricha)',
#        'insect - wants, cicade, bladluis (Hemiptera)', 'mijt (Acari)',
#        'vogel', 'zuigworm (Trematoda)', 'beenvis (Actinopterygii)',
#        'insect - dagvlinder', 'miljoenpoot', 'korstmos', 'spin (Araneae)',
#        'mos', 'kraakbeenvis  (Chondrichthyes)', 'platworm (Turbellaria)',
#        'varen', 'slurfworm (Kinorhyncha)', 'insect - haft (Ephemeroptera)',
#        'ribkwal (Ctenophora)', 'landzoogdier', 'slijmzwam', 'conifeer',
#        'reptiel', 'spons (Porifera)', 'slurfworm (Echiura)',
#        'insect - libel (Odonata)', 'zeespin (Pycnogonida)',
#        'mosdiertje (Bryozoa)', 'spuitworm (Sipuncula)',
#        'insect - kokerjuffer (Trichoptera)',
#        'insect - gaasvlieg (Neuroptera)', 'stekelhuidige',
#        'insect - houtluis (Psocoptera)',
#        'insect - waaiervleugelige (Strepsiptera)', 'kelkworm (Entoprocta)',
#        'kranswier', 'beerdiertje (Tardigrada)',
#        'brachiopood (Brachiopoda)', 'baardworm (Pogonophora)',
#        'snoerworm (Nemertinea)', 'insect - oorworm (Dermaptera)',
#        'insect - steenvlieg (Plecoptera)', 'manteldiertje (Urochordata)',
#        'zeezoogdier', 'insect - luis (Phthiraptera)',
#        'insect - sprinkhaan & krekel (Orthoptera)',
#        'kaakworm (Gnathostomulida)', 'tweestaart (Diplura)', 'pauropood',
#        'oerinsect (Protura)', 'loricifeer', 'duizendpoot',
#        'insect - schorpioenvlieg (Mecoptera)', 'wolfsklauw',
#        'paardenhaarworm (Nematomorpha)',
#        'insect - kakkerlak (Dictyoptera)', 'priapulid',
#        'insect - zilvervis (Thysanura)', 'niet toegewezen', 'hauwmos',
#        'eikelworm (Hemichordata)', 'hooiwagen (Opiliones)',
#        'middendiertje (Mesozoa)', 'pijlworm (Chaetognatha)',
#        'insect - rotsspringer (Archaeognatha)', 'ginkgo',
#        'parasitaire nematode (Nematoda)', 'dwergpotige (Symphyla)',
#        'rondbek (Agnatha)', 'biesvaren',
#        'insect - kameelhalsvlieg (Raphidioptera)',
#        'hoefijzerworm (Phoronida)', 'insect - wandelende tak (Phasmida)',
#        'lipklever (Cycliophora)', 'paardenstaart',
#        'insect - elzenvlieg (Megaloptera)', 'schorpioen',
#        'oerdiertje (Protozoa)', 'insect - bidsprinkhaan (Mantodea)',
#        'virus', 'ectoparasitaire platworm', 'ongedetermineerd', nan], dtype=object)

# %% [markdown]
# We introduce a mapping in between the INFORMAL GROUP defined by recorder and the kingdom we're dealing with:

# %%
mapping_kingdom = {'insect - kever (Coleoptera)' : 'Animalia',
                   'conifeer' : 'Plantae', 
                   'beenvis (Actinopterygii)' : 'Animalia', 
                   'vogel' : 'Animalia', 
                   'insect - nachtvlinder' : 'Animalia', 
                   'bloemplant' : 'Plantae',
                   'spin (Araneae)' : 'Animalia',
                   'insect - vlieg & mug (Diptera)' : 'Animalia', 
                   'diatomee' : 'Plantae',
                   'mollusk (Mollusca)' : 'Animalia',
                   'insect - dagvlinder' : 'Animalia', 
                   'insect - kokerjuffer (Trichoptera)' : 'Animalia',
                   'ringworm' : 'Animalia',
                   'mos' : 'Plantae',
                   'insect - wants, cicade, bladluis (Hemiptera)' : 'Animalia', 
                   'mijt (Acari)' : 'Animalia', 
                   'varen' : 'Plantae', 
                   'schaaldier' : 'Animalia', 
                   'landzoogdier' : 'Animalia', 
                   'kranswier' : 'Plantae',
                   'insect - sprinkhaan & krekel (Orthoptera)' : 'Animalia', 
                   'korstmos' : 'Plantae',
                   'platworm (Turbellaria)' : 'Animalia',
                   'insect - libel (Odonata)' : 'Animalia', 
                   'wier' : 'Plantae', 'paardenstaart' : 'Plantae',
                   'niet toegewezen': None, 
                   'levermos' : 'Plantae', 
                   'tweestaart (Diplura)' : 'Animalia',
                   'rondbek (Agnatha)' : 'Animalia', 
                   'duizendpoot' : 'Animalia', 
                   'wolfsklauw' : 'Plantae', 
                   'amfibie' : 'Animalia', 
                   'bacterie' : 'Bacteria',
                   'insect - nachtvlinder' : 'Animalia',
                   'reptiel' : 'Animalia',
                   'insect - vliesvleugelige (Hymenoptera)' : 'Animalia',
                   'zwam' : 'Fungi',
                   'kraakbeenvis  (Chondrichthyes)' : 'Animalia',
                   'rondworm (Nematoda)' : 'Animalia',
                   'virus' : 'Viruses',
                   'insect - steenvlieg (Plecoptera)' : 'Animalia',
                   'zeezoogdier' : 'Animalia',
                   'ginkgo' : 'Plantae',
                   'parasitaire nematode (Nematoda)' : 'Animalia',
                   'zuigworm (Trematoda)' : 'Animalia',
                   'biesvaren' : 'Plantae',
                   'neteldier (=cnidarian)' : 'Animalia',
                   'insect - trips (Thysanoptera)'  : 'Animalia',
                   'oerdiertje (Protozoa)' : 'Protozoa',
                   'hauwmos' : 'Plantae',
                   'lintworm (Cestoda)' : 'Animalia',
                   'manteldiertje (Urochordata)' : 'Animalia',
                   'stekelhuidige' : 'Animalia',
                   'ectoparasitaire platworm' : 'Animalia',
                   'ribkwal (Ctenophora)' : 'Animalia',
                   'mosdiertje (Bryozoa)' : 'Animalia',
                   'pseudoschorpioen (Pseudoscorpiones)' : 'Animalia',
                   'raderdiertje (Rotifera)' : 'Animalia',
                   'springstaart (Collembola)' : 'Animalia',
                   'foraminifeer' : 'Protozoa',
                   'insect - vlo (Siphonaptera)' : 'Animalia',
                   'fungoide' : 'Fungi', 
                   'buikhaarworm (Gastrotricha)' : 'Animalia',
                   'miljoenpoot' : 'Animalia',
                   'slurfworm (Kinorhyncha)' : 'Animalia',
                   'insect - haft (Ephemeroptera)' : 'Animalia',
                   'slijmzwam' : 'Protozoa',
                   'spons (Porifera)' : 'Animalia',
                   'slurfworm (Echiura)' : 'Animalia',
                   'zeespin (Pycnogonida)' : 'Animalia',
                   'spuitworm (Sipuncula)' : 'Animalia',
                   'insect - gaasvlieg (Neuroptera)' : 'Animalia',
                   'insect - houtluis (Psocoptera)' : 'Animalia',
                   'insect - waaiervleugelige (Strepsiptera)' : 'Animalia',
                   'kelkworm (Entoprocta)' : 'Animalia',
                   'beerdiertje (Tardigrada)' : 'Animalia',
                   'brachiopood (Brachiopoda)' : 'Animalia',
                   'baardworm (Pogonophora)' : 'Animalia',
                   'snoerworm (Nemertinea)' : 'Animalia',
                   'insect - oorworm (Dermaptera)' : 'Animalia',
                   'insect - luis (Phthiraptera)' : 'Animalia',
                   'kaakworm (Gnathostomulida)' : 'Animalia',
                   'pauropood' : 'Animalia',
                   'oerinsect (Protura)' : 'Animalia',
                   'loricifeer' : 'Animalia',
                   'insect - schorpioenvlieg (Mecoptera)' : 'Animalia',
                   'paardenhaarworm (Nematomorpha)' : 'Animalia',
                   'insect - kakkerlak (Dictyoptera)' : 'Animalia',
                   'priapulid' : 'Animalia',
                   'insect - zilvervis (Thysanura)' : 'Animalia',
                   'eikelworm (Hemichordata)' : 'Animalia',
                   'hooiwagen (Opiliones)' : 'Animalia',
                   'middendiertje (Mesozoa)' : 'Animalia',
                   'pijlworm (Chaetognatha)' : 'Animalia',
                   'insect - rotsspringer (Archaeognatha)' : 'Animalia',
                   'dwergpotige (Symphyla)' : 'Animalia',
                   'insect - kameelhalsvlieg (Raphidioptera)' : 'Animalia',
                   'hoefijzerworm (Phoronida)' : 'Animalia',
                   'insect - wandelende tak (Phasmida)' : 'Animalia',
                   'lipklever (Cycliophora)' : 'Animalia',
                   'insect - elzenvlieg (Megaloptera)' : 'Animalia',
                   'schorpioen' : 'Animalia',
                   'insect - bidsprinkhaan (Mantodea)' : 'Animalia',
                   'ongedetermineerd' : None,
                   np.nan : None
                    }

# %%
recorder_names['kingdom'] = recorder_names['TAXON_GROUP_NAME'].replace(mapping_kingdom)

# %%
recorder_names["kingdom"].unique()
# Out:
# array(['Plantae', 'Animalia', 'Protozoa', 'Fungi', 'Bacteria', None,
#        'Viruses'], dtype=object)

# %%
len(recorder_names)
# Out:
# 144135

# %%
recorder_names.head()
# Out:
#   RECOMMENDED_TAXON_VERSION_KEY             scientificName  \
# 0              NHMSYS0000456996                   Caylusea
# 1              NHMSYS0000900079     Listrognathus mactator
# 2              NBNSYS0100004462  Paratanytarsus dissimilis
# 3              NHMSYS0000603228   Gymnodinium colymbeticum
# 4              NHMSYS0000875969                 Formicinae
#
#                          TAXON_GROUP_NAME   kingdom
# 0                              bloemplant   Plantae
# 1  insect - vliesvleugelige (Hymenoptera)  Animalia
# 2          insect - vlieg & mug (Diptera)  Animalia
# 3                                    wier   Plantae
# 4  insect - vliesvleugelige (Hymenoptera)  Animalia

# %% [markdown]
# ## Asynchronuous performing the requests

# %% [markdown]
# As we went to request 144135 different names to the GBIF backbone, a asyncronious requesting should be possible in order to shorten the time to retrieve the results:

# %% [markdown]
# ## Minimal working example

# %% [markdown]
# The concept of an asyncronious request of the API as example:

# %%
class Collector():
    def __init__(self):
        self.data = {}

    async def fetch(self, session, name, kingdom, idx):
        parameters = {'verbose': False, 'strict': True, 'name' : name, 'kingdom': kingdom}
        async with client.get('http://api.gbif.org/v1/species/match', params=parameters) as resp:
            if resp.status != 200:
                print(await resp.reason)
            else:
                #print(await resp.json())
                self.data[idx] = await resp.json()

# %%
testcase = recorder_names.iloc[:100,:]

# %%
names = testcase["scientificName"].values.tolist()
kingdoms = testcase["kingdom"].values.tolist()
inbo_idx = testcase["RECOMMENDED_TAXON_VERSION_KEY"].values.tolist()

# %%
test = Collector()
with aiohttp.ClientSession() as client:
    asyncio.get_event_loop().run_until_complete(asyncio.gather(
            *[test.fetch(client, name, kingdom, idx) for name, kingdom, idx in zip(names, kingdoms, inbo_idx)], 
            return_exceptions=True))

# %%
len(test.data)
# Out:
# 100

# %%
test.data
# Out:
# {'BMSSYS0000002618': {'canonicalName': 'Bolbitius conocephalus',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Bolbitiaceae',
#   'familyKey': 8440,
#   'genus': 'Galerella',
#   'genusKey': 7858530,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Bolbitius conocephalus (Bull.) Fr., 1874',
#   'species': 'Galerella conocephala',
#   'speciesKey': 5449507,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 2529985},
#  'BMSSYS0000005241': {'canonicalName': 'Crepidotus tubidulus',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Inocybaceae',
#   'familyKey': 4177,
#   'genus': 'Crepidotus',
#   'genusKey': 8181205,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Crepidotus tubidulus anon.',
#   'species': 'Crepidotus tubidulus',
#   'speciesKey': 5453111,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5453111},
#  'BMSSYS0000009346': {'canonicalName': 'Lagenocystis',
#   'confidence': 96,
#   'family': 'Lagenidiaceae',
#   'familyKey': 3304045,
#   'genus': 'Lagenocystis',
#   'genusKey': 8367700,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'phylum': 'Chytridiomycota',
#   'phylumKey': 94,
#   'rank': 'GENUS',
#   'scientificName': 'Lagenocystis Copeland, 1956',
#   'status': 'DOUBTFUL',
#   'synonym': False,
#   'usageKey': 8367700},
#  'BMSSYS0000012294': {'canonicalName': 'Olpidium gregarium',
#   'class': 'Chytridiomycetes',
#   'classKey': 318,
#   'confidence': 100,
#   'family': 'Olpidiaceae',
#   'familyKey': 1958,
#   'genus': 'Olpidium',
#   'genusKey': 7517482,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Olpidiales',
#   'orderKey': 8137353,
#   'phylum': 'Chytridiomycota',
#   'phylumKey': 94,
#   'rank': 'SPECIES',
#   'scientificName': 'Olpidium gregarium (Nowak.) J. Schrรถt., 1886',
#   'species': 'Olpidium gregarium',
#   'speciesKey': 2626989,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2626989},
#  'BMSSYS0000017651': {'confidence': 100,
#   'matchType': 'NONE',
#   'synonym': False},
#  'BMSSYS0000020052': {'canonicalName': 'Dacampiaceae',
#   'class': 'Dothideomycetes',
#   'classKey': 183,
#   'confidence': 99,
#   'family': 'Dacampiaceae',
#   'familyKey': 8355,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Pleosporales',
#   'orderKey': 1047,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'FAMILY',
#   'scientificName': 'Dacampiaceae',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 8355},
#  'BMSSYS0000020238': {'canonicalName': 'Mycosphaerellaceae',
#   'class': 'Dothideomycetes',
#   'classKey': 183,
#   'confidence': 99,
#   'family': 'Mycosphaerellaceae',
#   'familyKey': 4797,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Capnodiales',
#   'orderKey': 1262,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'FAMILY',
#   'scientificName': 'Mycosphaerellaceae',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4797},
#  'INBSYS0000004622': {'canonicalName': 'Panicum clandestinum',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 99,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Panicum',
#   'genusKey': 2705064,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Panicum clandestinum L.',
#   'species': 'Panicum clandestinum',
#   'speciesKey': 2702544,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2702544},
#  'INBSYS0000016073': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000018507': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000019394': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000022144': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000026309': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000026806': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'INBSYS0000041284': {'canonicalName': 'Cryptocephalus marginatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Chrysomelidae',
#   'familyKey': 7780,
#   'genus': 'Cryptocephalus',
#   'genusKey': 1048649,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Cryptocephalus marginatus Fabricius, 1781',
#   'species': 'Cryptocephalus marginatus',
#   'speciesKey': 6097748,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 6097748},
#  'INBSYS0000041698': {'canonicalName': 'Noxius curtirostris',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Anthribidae',
#   'familyKey': 4206,
#   'genus': 'Noxius',
#   'genusKey': 1167403,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Noxius curtirostris (Mulsant & Rey, 1861)',
#   'species': 'Noxius curtirostris',
#   'speciesKey': 4469442,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4469442},
#  'INBSYS0000044669': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'NBNSYS0000002105': {'canonicalName': 'Sagittaria sagittifolia',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 99,
#   'family': 'Alismataceae',
#   'familyKey': 3720,
#   'genus': 'Sagittaria',
#   'genusKey': 2766037,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Alismatales',
#   'orderKey': 551,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Sagittaria sagittifolia L.',
#   'species': 'Sagittaria sagittifolia',
#   'speciesKey': 5328882,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5328882},
#  'NBNSYS0000002409': {'canonicalName': 'Cladium mariscus',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 99,
#   'family': 'Cyperaceae',
#   'familyKey': 7708,
#   'genus': 'Cladium',
#   'genusKey': 2731321,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Cladium mariscus (L.) Pohl',
#   'species': 'Cladium mariscus',
#   'speciesKey': 2731327,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2731327},
#  'NBNSYS0000004529': {'canonicalName': 'Tragopogon pratensis orientalis',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 100,
#   'family': 'Asteraceae',
#   'familyKey': 3065,
#   'genus': 'Reichardia',
#   'genusKey': 2965909,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Asterales',
#   'orderKey': 414,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SUBSPECIES',
#   'scientificName': 'Tragopogon pratensis subsp. orientalis (L.) Celak.',
#   'species': 'Reichardia tingitana',
#   'speciesKey': 5385648,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 5709399},
#  'NBNSYS0000007131': {'canonicalName': 'Carabus cancellatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Carabidae',
#   'familyKey': 3792,
#   'genus': 'Carabus',
#   'genusKey': 1036775,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Carabus (Tachypus) cancellatus Illiger, 1798',
#   'species': 'Carabus cancellatus',
#   'speciesKey': 4470480,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4470480},
#  'NBNSYS0000007850': {'canonicalName': 'Chrysopilus cristatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Rhagionidae',
#   'familyKey': 5587,
#   'genus': 'Chrysopilus',
#   'genusKey': 5078728,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Chrysopilus cristatus (Fabricius, 1775)',
#   'species': 'Chrysopilus cristatus',
#   'speciesKey': 5766100,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5766100},
#  'NBNSYS0000009253': {'canonicalName': 'Anteon pubicorne',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Dryinidae',
#   'familyKey': 4340,
#   'genus': 'Anteon',
#   'genusKey': 4407245,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Anteon pubicorne (Dalman, 1818)',
#   'species': 'Anteon pubicorne',
#   'speciesKey': 4493259,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4493259},
#  'NBNSYS0000010064': {'canonicalName': 'Anaptus major',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Nabidae',
#   'familyKey': 7891,
#   'genus': 'Anaptus',
#   'genusKey': 2021017,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hemiptera',
#   'orderKey': 809,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Anaptus major (Costa, 1842)',
#   'species': 'Anaptus major',
#   'speciesKey': 2021018,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2021018},
#  'NBNSYS0000010630': {'canonicalName': 'Kybos strigilifer',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Cicadellidae',
#   'familyKey': 9647,
#   'genus': 'Kybos',
#   'genusKey': 2046550,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hemiptera',
#   'orderKey': 809,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Kybos strigilifer (Ossiannilsson, 1941)',
#   'species': 'Kybos strigilifer',
#   'speciesKey': 2046678,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2046678},
#  'NBNSYS0000014001': {'canonicalName': 'Papaver dubium',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 99,
#   'family': 'Papaveraceae',
#   'familyKey': 2422,
#   'genus': 'Papaver',
#   'genusKey': 2888431,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Ranunculales',
#   'orderKey': 399,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Papaver dubium L.',
#   'species': 'Papaver dubium',
#   'speciesKey': 2888464,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2888464},
#  'NBNSYS0000014420': {'canonicalName': 'Poa flabellata',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 99,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Poa',
#   'genusKey': 2704173,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Poa flabellata (Lam.) Raspail',
#   'species': 'Poa flabellata',
#   'speciesKey': 2704228,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2704228},
#  'NBNSYS0000015704': {'canonicalName': 'Diaporthe phaseolorum',
#   'class': 'Sordariomycetes',
#   'classKey': 320,
#   'confidence': 100,
#   'family': 'Diaporthaceae',
#   'familyKey': 4146,
#   'genus': 'Phomopsis',
#   'genusKey': 7237605,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Diaporthales',
#   'orderKey': 1289,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Diaporthe phaseolorum (Cooke & Ellis) Sacc., 1882',
#   'species': 'Phomopsis phaseoli',
#   'speciesKey': 3444030,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 3444449},
#  'NBNSYS0000017545': {'canonicalName': 'Mollisia caricina',
#   'class': 'Leotiomycetes',
#   'classKey': 179,
#   'confidence': 100,
#   'family': 'Dermateaceae',
#   'familyKey': 4121,
#   'genus': 'Mollisia',
#   'genusKey': 2561289,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Helotiales',
#   'orderKey': 1052,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Mollisia caricina Fautrey, 1891',
#   'species': 'Mollisia caricina',
#   'speciesKey': 2585014,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2585014},
#  'NBNSYS0000017788': {'canonicalName': 'Pseudopeziza calthae',
#   'class': 'Leotiomycetes',
#   'classKey': 179,
#   'confidence': 100,
#   'family': 'Dermateaceae',
#   'familyKey': 4121,
#   'genus': 'Pseudopeziza',
#   'genusKey': 2569968,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Helotiales',
#   'orderKey': 1052,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Pseudopeziza calthae (W. Phillips) Massee, 1895',
#   'species': 'Pseudopeziza calthae',
#   'speciesKey': 2581183,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2581183},
#  'NBNSYS0000017951': {'canonicalName': 'Velutarina rufo-olivacea',
#   'class': 'Leotiomycetes',
#   'classKey': 179,
#   'confidence': 100,
#   'family': 'Helotiaceae',
#   'familyKey': 8381,
#   'genus': 'Velutarina',
#   'genusKey': 2582033,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Helotiales',
#   'orderKey': 1052,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Velutarina rufo-olivacea (Alb. & Schwein.) Korf, 1971',
#   'species': 'Velutarina rufo-olivacea',
#   'speciesKey': 2582036,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2582036},
#  'NBNSYS0000018025': {'canonicalName': 'Nectria funicola',
#   'class': 'Sordariomycetes',
#   'classKey': 320,
#   'confidence': 100,
#   'family': 'Nectriaceae',
#   'familyKey': 4152,
#   'genus': 'Nectria',
#   'genusKey': 2560952,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Hypocreales',
#   'orderKey': 1290,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Nectria funicola Berk. & Broome, 1860',
#   'species': 'Nectria funicola',
#   'speciesKey': 5251796,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5251796},
#  'NBNSYS0000019270': {'canonicalName': 'Cryptodiscus microstomus',
#   'class': 'Lecanoromycetes',
#   'classKey': 180,
#   'confidence': 100,
#   'family': 'Stictidaceae',
#   'familyKey': 8390,
#   'genus': 'Cryptodiscus',
#   'genusKey': 2561290,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Ostropales',
#   'orderKey': 1279,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Cryptodiscus microstomus (Carmich. ex Berk.) Sacc.',
#   'species': 'Cryptodiscus microstomus',
#   'speciesKey': 5476645,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5476645},
#  'NBNSYS0000023841': {'canonicalName': 'Atheta luteipes',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Staphylinidae',
#   'familyKey': 7854,
#   'genus': 'Dilacra',
#   'genusKey': 1040396,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Atheta luteipes (Erichson, 1837)',
#   'species': 'Dilacra luteipes',
#   'speciesKey': 7810161,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 6097458},
#  'NBNSYS0000024014': {'canonicalName': 'Ocalea picata',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Staphylinidae',
#   'familyKey': 7854,
#   'genus': 'Sphaerobulbus',
#   'genusKey': 4715397,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Ocalea picata (Stephens, 1832)',
#   'species': 'Sphaerobulbus businskorum',
#   'speciesKey': 7203905,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 6097628},
#  'NBNSYS0000024510': {'canonicalName': 'Glischrochilus quadripunctatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Nitidulidae',
#   'familyKey': 7840,
#   'genus': 'Glischrochilus',
#   'genusKey': 4405985,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Glischrochilus quadripunctatus (Linnaeus, 1758)',
#   'species': 'Glischrochilus quadripunctatus',
#   'speciesKey': 4453169,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4453169},
#  'NBNSYS0000024535': {'canonicalName': 'Hypocoprus latridioides',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Cryptophagidae',
#   'familyKey': 7784,
#   'genus': 'Hypocoprus',
#   'genusKey': 4406757,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Hypocoprus latridioides Motschulsky, 1839',
#   'species': 'Hypocoprus latridioides',
#   'speciesKey': 4451825,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4451825},
#  'NBNSYS0000025524': {'canonicalName': 'Rhamphus pulicarius',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 97,
#   'family': 'Curculionidae',
#   'familyKey': 4239,
#   'genus': 'Rhamphus',
#   'genusKey': 1209345,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'note': '2 synonym homonyms',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Rhamphus pulicarius Norman, H. Joy. , 1932',
#   'species': 'Rhamphus pulicarius',
#   'speciesKey': 1209351,
#   'status': 'DOUBTFUL',
#   'synonym': False,
#   'usageKey': 1209351},
#  'NBNSYS0000025728': {'confidence': 100,
#   'matchType': 'NONE',
#   'synonym': False},
#  'NBNSYS0000026523': {'canonicalName': 'Ditula angustiorana',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Tortricidae',
#   'familyKey': 5343,
#   'genus': 'Ditula',
#   'genusKey': 1741043,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Lepidoptera',
#   'orderKey': 797,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Ditula angustiorana Haworth, 1811',
#   'species': 'Ditula angustiorana',
#   'speciesKey': 1741056,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1741056},
#  'NBNSYS0000027152': {'canonicalName': 'Forcipomyia braueri',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ceratopogonidae',
#   'familyKey': 3340,
#   'genus': 'Forcipomyia',
#   'genusKey': 1633624,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Forcipomyia braueri (Wasmann, 1893)',
#   'species': 'Forcipomyia braueri',
#   'speciesKey': 1634580,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1634580},
#  'NBNSYS0000027940': {'canonicalName': 'Lestodiplosis affinis',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Cecidomyiidae',
#   'familyKey': 3338,
#   'genus': 'Lestodiplosis',
#   'genusKey': 1593713,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Lestodiplosis affinis Barnes, 1928',
#   'species': 'Lestodiplosis affinis',
#   'speciesKey': 1593757,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1593757},
#  'NBNSYS0000029133': {'canonicalName': 'Copromyza stercoraria',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Sphaeroceridae',
#   'familyKey': 6924,
#   'genus': 'Copromyza',
#   'genusKey': 1562124,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Copromyza stercoraria (Meigen, 1830)',
#   'species': 'Copromyza stercoraria',
#   'speciesKey': 1589700,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1589700},
#  'NBNSYS0000031624': {'canonicalName': 'Diphyus gradatorius',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Diphyus',
#   'genusKey': 1296237,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Diphyus gradatorius (Thunberg, 1822)',
#   'species': 'Diphyus gradatorius',
#   'speciesKey': 1296473,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1296473},
#  'NBNSYS0000032386': {'canonicalName': 'Pteromalus bifoveolatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Pteromalidae',
#   'familyKey': 9447,
#   'genus': 'Pteromalus',
#   'genusKey': 1394398,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Pteromalus bifoveolatus Fรถrster, 1861',
#   'species': 'Pteromalus bifoveolatus',
#   'speciesKey': 4500845,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4500845},
#  'NBNSYS0000037014': {'canonicalName': 'Lumbriculus variegatus',
#   'class': 'Clitellata',
#   'classKey': 255,
#   'confidence': 100,
#   'family': 'Lumbriculidae',
#   'familyKey': 6964,
#   'genus': 'Lumbriculus',
#   'genusKey': 2308018,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Lumbriculida',
#   'orderKey': 473,
#   'phylum': 'Annelida',
#   'phylumKey': 42,
#   'rank': 'SPECIES',
#   'scientificName': 'Lumbriculus variegatus (MĂźller, 1774)',
#   'species': 'Lumbriculus variegatus',
#   'speciesKey': 2308023,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2308023},
#  'NBNSYS0000131913': {'canonicalName': 'Cordyline',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 95,
#   'family': 'Asparagaceae',
#   'familyKey': 7683,
#   'genus': 'Cordyline',
#   'genusKey': 2766216,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Asparagales',
#   'orderKey': 1169,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'GENUS',
#   'scientificName': 'Cordyline Comm. ex R. Br.',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2766216},
#  'NBNSYS0000133501': {'canonicalName': 'Gregopimpla',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 98,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Gregopimpla',
#   'genusKey': 1275622,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Gregopimpla Momoi, 1965',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1275622},
#  'NBNSYS0000135003': {'canonicalName': 'Melanthrips',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 98,
#   'family': 'Melanthripidae',
#   'familyKey': 7954,
#   'genus': 'Melanthrips',
#   'genusKey': 1420446,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Thysanoptera',
#   'orderKey': 1228,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Melanthrips Haliday, 1836',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1420446},
#  'NBNSYS0000137203': {'canonicalName': 'Pyrenula',
#   'class': 'Eurotiomycetes',
#   'classKey': 178,
#   'confidence': 96,
#   'family': 'Pyrenulaceae',
#   'familyKey': 8352,
#   'genus': 'Pyrenula',
#   'genusKey': 7528084,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Pyrenulales',
#   'orderKey': 1044,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'GENUS',
#   'scientificName': 'Pyrenula A.Massal.',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 7528084},
#  'NBNSYS0000139277': {'canonicalName': 'Aceria',
#   'class': 'Arachnida',
#   'classKey': 367,
#   'confidence': 98,
#   'family': 'Eriophyidae',
#   'familyKey': 2816,
#   'genus': 'Aceria',
#   'genusKey': 2128489,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Prostigmata',
#   'orderKey': 372,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Aceria Keifer, 1944',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2128489},
#  'NBNSYS0000160045': {'canonicalName': 'Gastrotricha',
#   'confidence': 98,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'phylum': 'Gastrotricha',
#   'phylumKey': 22,
#   'rank': 'PHYLUM',
#   'scientificName': 'Gastrotricha',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 22},
#  'NBNSYS0000162509': {'canonicalName': 'Alytes cisternasii',
#   'class': 'Amphibia',
#   'classKey': 131,
#   'confidence': 100,
#   'family': 'Alytidae',
#   'familyKey': 6726,
#   'genus': 'Alytes',
#   'genusKey': 2426608,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Anura',
#   'orderKey': 952,
#   'phylum': 'Chordata',
#   'phylumKey': 44,
#   'rank': 'SPECIES',
#   'scientificName': 'Alytes cisternasii Boscรก, 1879',
#   'species': 'Alytes cisternasii',
#   'speciesKey': 2426610,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2426610},
#  'NBNSYS0000179869': {'canonicalName': 'Brachionis leydigi',
#   'class': 'Eurotatoria',
#   'classKey': 307,
#   'confidence': 100,
#   'family': 'Brachionidae',
#   'familyKey': 3880,
#   'genus': 'Brachionus',
#   'genusKey': 1000593,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Ploima',
#   'orderKey': 1235,
#   'phylum': 'Rotifera',
#   'phylumKey': 91,
#   'rank': 'SPECIES',
#   'scientificName': 'Brachionis leydigi Cohn, 1862',
#   'species': 'Brachionus leydigii',
#   'speciesKey': 4984176,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 8257987},
#  'NBNSYS0000184802': {'canonicalName': 'Odontophora',
#   'class': 'Adenophorea',
#   'classKey': 251,
#   'confidence': 96,
#   'family': 'Axonolaimidae',
#   'familyKey': 6519,
#   'genus': 'Odontophora',
#   'genusKey': 5188533,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Araeolaimida',
#   'orderKey': 978,
#   'phylum': 'Nematoda',
#   'phylumKey': 5967481,
#   'rank': 'GENUS',
#   'scientificName': 'Odontophora BÃ¼tschli, 1874',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5188533},
#  'NBNSYS0000185242': {'canonicalName': 'Parametaphoxus',
#   'class': 'Malacostraca',
#   'classKey': 229,
#   'confidence': 96,
#   'family': 'Phoxocephalidae',
#   'familyKey': 8010,
#   'genus': 'Parametaphoxus',
#   'genusKey': 7910433,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Amphipoda',
#   'orderKey': 1231,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Parametaphoxus Jarrett & Bousfield, 1994',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 7910433},
#  'NBNSYS0000185509': {'canonicalName': 'Periplomatidae',
#   'class': 'Bivalvia',
#   'classKey': 137,
#   'confidence': 99,
#   'family': 'Periplomatidae',
#   'familyKey': 6865,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Anomalodesmata',
#   'orderKey': 8367546,
#   'phylum': 'Mollusca',
#   'phylumKey': 52,
#   'rank': 'FAMILY',
#   'scientificName': 'Periplomatidae',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 6865},
#  'NBNSYS0100000437': {'canonicalName': 'Anurophorus satchelli',
#   'class': 'Entognatha',
#   'classKey': 290,
#   'confidence': 100,
#   'family': 'Isotomidae',
#   'familyKey': 7214,
#   'genus': 'Anurophorus',
#   'genusKey': 5166805,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Collembola',
#   'orderKey': 546,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Anurophorus satchelli Goto, 1956',
#   'species': 'Anurophorus satchelli',
#   'speciesKey': 5166810,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5166810},
#  'NBNSYS0100004462': {'canonicalName': 'Paratanytarsus dissimilis',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Chironomidae',
#   'familyKey': 3343,
#   'genus': 'Tanytarsus',
#   'genusKey': 1451718,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Paratanytarsus dissimilis (Johannsen, 1905)',
#   'species': 'Tanytarsus dissimilis',
#   'speciesKey': 1451993,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 4297556},
#  'NBNSYS0200002720': {'canonicalName': 'Oenothera drummondii',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 99,
#   'family': 'Onagraceae',
#   'familyKey': 2430,
#   'genus': 'Oenothera',
#   'genusKey': 3188799,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Myrtales',
#   'orderKey': 690,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Oenothera drummondii Hook.',
#   'species': 'Oenothera drummondii',
#   'speciesKey': 3188857,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3188857},
#  'NBNSYS0200003136': {'canonicalName': 'Senna obtusifolia',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 100,
#   'family': 'Fabaceae',
#   'familyKey': 5386,
#   'genus': 'Senna',
#   'genusKey': 2956904,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Fabales',
#   'orderKey': 1370,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Senna obtusifolia (L.)H.S.Irwin & Barneby',
#   'species': 'Senna obtusifolia',
#   'speciesKey': 2957408,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2957408},
#  'NBNSYS0200003680': {'canonicalName': 'Crypsis schoenoides',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 99,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Crypsis',
#   'genusKey': 2706115,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Crypsis schoenoides (L.) Lam.',
#   'species': 'Crypsis schoenoides',
#   'speciesKey': 5290185,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5290185},
#  'NHMSYS0000067185': {'canonicalName': 'Ammonia flevensis',
#   'class': 'Globothalamea',
#   'classKey': 7434778,
#   'confidence': 100,
#   'family': 'Rotaliidae',
#   'familyKey': 7475854,
#   'genus': 'Ammonia',
#   'genusKey': 7919155,
#   'kingdom': 'Chromista',
#   'kingdomKey': 4,
#   'matchType': 'EXACT',
#   'order': 'Rotaliida',
#   'orderKey': 7692889,
#   'phylum': 'Foraminifera',
#   'phylumKey': 8376456,
#   'rank': 'SPECIES',
#   'scientificName': 'Ammonia flevensis (Hofker, 1930)',
#   'species': 'Ammonia flevensis',
#   'speciesKey': 8119745,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 8119745},
#  'NHMSYS0000068236': {'canonicalName': 'Tritaphros retzii',
#   'class': 'Cestoda',
#   'classKey': 144,
#   'confidence': 100,
#   'family': 'Rhinobothriidae',
#   'familyKey': 6481842,
#   'genus': 'Tritaphros',
#   'genusKey': 4344888,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Rhinebothriidea',
#   'orderKey': 8263452,
#   'phylum': 'Platyhelminthes',
#   'phylumKey': 108,
#   'rank': 'SPECIES',
#   'scientificName': 'Tritaphros retzii Lรถnnberg, 1889',
#   'species': 'Tritaphros retzii',
#   'speciesKey': 4344889,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4344889},
#  'NHMSYS0000068458': {'canonicalName': 'Scutellonema',
#   'class': 'Secernentea',
#   'classKey': 250,
#   'confidence': 98,
#   'family': 'Hoplolaimidae',
#   'familyKey': 6465,
#   'genus': 'Scutellonema',
#   'genusKey': 2284129,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Tylenchida',
#   'orderKey': 972,
#   'phylum': 'Nematoda',
#   'phylumKey': 5967481,
#   'rank': 'GENUS',
#   'scientificName': 'Scutellonema Andrรกssy, 1958',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2284129},
#  'NHMSYS0000068760': {'canonicalName': 'Plectus tenuis',
#   'class': 'Adenophorea',
#   'classKey': 251,
#   'confidence': 99,
#   'family': 'Plectidae',
#   'familyKey': 2607,
#   'genus': 'Plectus',
#   'genusKey': 2283075,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Araeolaimida',
#   'orderKey': 978,
#   'phylum': 'Nematoda',
#   'phylumKey': 5967481,
#   'rank': 'SPECIES',
#   'scientificName': 'Plectus tenuis Bastian, 1865',
#   'species': 'Plectus tenuis',
#   'speciesKey': 5188562,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5188562},
#  'NHMSYS0000079019': {'canonicalName': 'Jassidophaga',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 98,
#   'family': 'Pipunculidae',
#   'familyKey': 5583,
#   'genus': 'Jassidophaga',
#   'genusKey': 8385827,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Jassidophaga Enderlein, 1936',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 8385827},
#  'NHMSYS0000304909': {'canonicalName': 'Sphenotrochus andrewianus',
#   'class': 'Anthozoa',
#   'classKey': 206,
#   'confidence': 100,
#   'family': 'Turbinoliidae',
#   'familyKey': 3354,
#   'genus': 'Sphenotrochus',
#   'genusKey': 2259307,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Scleractinia',
#   'orderKey': 714,
#   'phylum': 'Cnidaria',
#   'phylumKey': 43,
#   'rank': 'SPECIES',
#   'scientificName': 'Sphenotrochus andrewianus Milne Edwards & Haime, 1848',
#   'species': 'Sphenotrochus andrewianus',
#   'speciesKey': 2259308,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2259308},
#  'NHMSYS0000304931': {'canonicalName': 'Tima',
#   'class': 'Hydrozoa',
#   'classKey': 205,
#   'confidence': 96,
#   'family': 'Eirenidae',
#   'familyKey': 8191,
#   'genus': 'Tima',
#   'genusKey': 2268431,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Leptothecata',
#   'orderKey': 712,
#   'phylum': 'Cnidaria',
#   'phylumKey': 43,
#   'rank': 'GENUS',
#   'scientificName': 'Tima Eschscholtz, 1829',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2268431},
#  'NHMSYS0000309359': {'canonicalName': 'Anthelia juratzkana',
#   'class': 'Jungermanniopsida',
#   'classKey': 126,
#   'confidence': 100,
#   'family': 'Antheliaceae',
#   'familyKey': 6142,
#   'genus': 'Anthelia',
#   'genusKey': 2689309,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Jungermanniales',
#   'orderKey': 381,
#   'phylum': 'Marchantiophyta',
#   'phylumKey': 9,
#   'rank': 'SPECIES',
#   'scientificName': 'Anthelia juratzkana (Limpr.) Trevis.',
#   'species': 'Anthelia juratzkana',
#   'speciesKey': 5710214,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5710214},
#  'NHMSYS0000356730': {'canonicalName': 'Dinocheirus',
#   'class': 'Arachnida',
#   'classKey': 367,
#   'confidence': 98,
#   'family': 'Chernetidae',
#   'familyKey': 3691,
#   'genus': 'Dinocheirus',
#   'genusKey': 2127154,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Pseudoscorpiones',
#   'orderKey': 1161,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Dinocheirus Chamberlin, 1929',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2127154},
#  'NHMSYS0000456996': {'canonicalName': 'Caylusea',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 98,
#   'family': 'Resedaceae',
#   'familyKey': 3110,
#   'genus': 'Caylusea',
#   'genusKey': 7275943,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Brassicales',
#   'orderKey': 7225535,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'GENUS',
#   'scientificName': 'Caylusea A. St.-Hil.',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 7275943},
#  'NHMSYS0000464507': {'canonicalName': 'Trachyspermum',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 98,
#   'family': 'Apiaceae',
#   'familyKey': 6720,
#   'genus': 'Trachyspermum',
#   'genusKey': 3034237,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Apiales',
#   'orderKey': 1351,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'GENUS',
#   'scientificName': 'Trachyspermum Link',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3034237},
#  'NHMSYS0000502699': {'canonicalName': 'Furcula',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 98,
#   'family': 'Notodontidae',
#   'familyKey': 7016,
#   'genus': 'Furcula',
#   'genusKey': 1822545,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Lepidoptera',
#   'orderKey': 797,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Furcula Lamarck, 1816',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1822545},
#  'NHMSYS0000524830': {'canonicalName': 'Snowella',
#   'class': 'Cyanophyceae',
#   'classKey': 7550188,
#   'confidence': 98,
#   'family': 'Merismopediaceae',
#   'familyKey': 7108,
#   'genus': 'Snowella',
#   'genusKey': 3217087,
#   'kingdom': 'Bacteria',
#   'kingdomKey': 3,
#   'matchType': 'EXACT',
#   'order': 'Chroococcales',
#   'orderKey': 746,
#   'phylum': 'Cyanobacteria',
#   'phylumKey': 68,
#   'rank': 'GENUS',
#   'scientificName': 'Snowella Elenkin, 1938',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3217087},
#  'NHMSYS0000530461': {'canonicalName': 'Luscinia calliope',
#   'class': 'Aves',
#   'classKey': 212,
#   'confidence': 100,
#   'family': 'Muscicapidae',
#   'familyKey': 9322,
#   'genus': 'Luscinia',
#   'genusKey': 5429330,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Passeriformes',
#   'orderKey': 729,
#   'phylum': 'Chordata',
#   'phylumKey': 44,
#   'rank': 'SPECIES',
#   'scientificName': 'Luscinia calliope (Pallas, 1776)',
#   'species': 'Luscinia calliope',
#   'speciesKey': 2492537,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2492537},
#  'NHMSYS0000545918': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'NHMSYS0000602615': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'NHMSYS0000603228': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'NHMSYS0000604429': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'NHMSYS0000875654': {'canonicalName': 'Chrysis angustula',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Masaridae',
#   'familyKey': 8579,
#   'genus': 'Chrysis',
#   'genusKey': 6725842,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Chrysis angustula Schenck, 1856',
#   'species': 'Chrysis angustula',
#   'speciesKey': 5870014,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5870014},
#  'NHMSYS0000875969': {'confidence': 100,
#   'matchType': 'NONE',
#   'synonym': False},
#  'NHMSYS0000898472': {'canonicalName': 'Diadegma lithocolletis',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Diadegma',
#   'genusKey': 1290824,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Diadegma lithocolletis Horstmann, 1969',
#   'species': 'Diadegma lithocolletis',
#   'speciesKey': 1291090,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1291090},
#  'NHMSYS0000900079': {'canonicalName': 'Listrognathus mactator',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Listrognathus',
#   'genusKey': 1306649,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Listrognathus mactator (Thunberg, 1822)',
#   'species': 'Listrognathus mactator',
#   'speciesKey': 1306714,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1306714},
#  'NHMSYS0000900594': {'canonicalName': 'Olesicampe femorella',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Olesicampe',
#   'genusKey': 1291826,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Olesicampe femorella (Thomson, 1887)',
#   'species': 'Olesicampe femorella',
#   'speciesKey': 1291865,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1291865},
#  'NHMSYS0001477100': {'canonicalName': 'Ceratostomataceae',
#   'class': 'Sordariomycetes',
#   'classKey': 320,
#   'confidence': 99,
#   'family': 'Ceratostomataceae',
#   'familyKey': 4155,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Melanosporales',
#   'orderKey': 840,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'FAMILY',
#   'scientificName': 'Ceratostomataceae',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4155},
#  'NHMSYS0001477692': {'canonicalName': 'Cladosporium aecidiicola',
#   'class': 'Dothideomycetes',
#   'classKey': 183,
#   'confidence': 100,
#   'family': 'Cladosporiaceae',
#   'familyKey': 3563987,
#   'genus': 'Cladosporium',
#   'genusKey': 2518208,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Capnodiales',
#   'orderKey': 1262,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Cladosporium aecidiicola ThĂźm., 1876',
#   'species': 'Cladosporium aecidiicola',
#   'speciesKey': 2620475,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2620475},
#  'NHMSYS0001478442': {'canonicalName': 'Collybia paupertina',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Tricholomataceae',
#   'familyKey': 8787,
#   'genus': 'Collybia',
#   'genusKey': 2527585,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Collybia paupertina A. Pearson, 1952',
#   'species': 'Collybia paupertina',
#   'speciesKey': 3325299,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3325299},
#  'NHMSYS0001482692': {'canonicalName': 'Galerina camerina',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 99,
#   'family': 'Cortinariaceae',
#   'familyKey': 4172,
#   'genus': 'Galerina',
#   'genusKey': 2524117,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Galerina camerina (Fr.) KÃ¼hner, 1955',
#   'species': 'Galerina camerina',
#   'speciesKey': 2533876,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2533876},
#  'NHMSYS0001482894': {'canonicalName': 'Geopora ploettneriana',
#   'class': 'Pezizomycetes',
#   'classKey': 316,
#   'confidence': 100,
#   'family': 'Pyronemataceae',
#   'familyKey': 4131,
#   'genus': 'Geopora',
#   'genusKey': 2593329,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Pezizales',
#   'orderKey': 1057,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Geopora ploettneriana ined.',
#   'species': 'Geopora ploettneriana',
#   'speciesKey': 5499796,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5499796},
#  'NHMSYS0001487579': {'canonicalName': 'Leptosphaeria',
#   'class': 'Dothideomycetes',
#   'classKey': 183,
#   'confidence': 96,
#   'family': 'Leptosphaeriaceae',
#   'familyKey': 8307,
#   'genus': 'Leptosphaeria',
#   'genusKey': 7981442,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Pleosporales',
#   'orderKey': 1047,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'GENUS',
#   'scientificName': 'Leptosphaeria Cesati & de Notaris, 1863',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 7981442},
#  'NHMSYS0001490011': {'canonicalName': 'Mycena aciculata',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Mycenaceae',
#   'familyKey': 4180,
#   'genus': 'Mycena',
#   'genusKey': 5955261,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Mycena aciculata (A.H. Sm.) Desjardin & E. Horak, 2002',
#   'species': 'Mycena aciculata',
#   'speciesKey': 2527097,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2527097},
#  'NHMSYS0001490826': {'canonicalName': 'Nephromataceae',
#   'class': 'Lecanoromycetes',
#   'classKey': 180,
#   'confidence': 99,
#   'family': 'Nephromataceae',
#   'familyKey': 8374,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Peltigerales',
#   'orderKey': 1055,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'FAMILY',
#   'scientificName': 'Nephromataceae',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 8374},
#  'NHMSYS0001495662': {'canonicalName': 'Puccinia pazschkei jueliana',
#   'class': 'Pucciniomycetes',
#   'classKey': 270,
#   'confidence': 100,
#   'family': 'Pucciniaceae',
#   'familyKey': 3251,
#   'genus': 'Puccinia',
#   'genusKey': 2513570,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Pucciniales',
#   'orderKey': 1126,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'VARIETY',
#   'scientificName': 'Puccinia pazschkei var. jueliana (Dietel) Savile, 1954',
#   'species': 'Puccinia pazschkei',
#   'speciesKey': 3376286,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 3379774},
#  'NHMSYS0001499812': {'canonicalName': 'Tomentella subfusca',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Thelephoraceae',
#   'familyKey': 3277,
#   'genus': 'Tomentella',
#   'genusKey': 8171593,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Thelephorales',
#   'orderKey': 530,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Tomentella subfusca (Pers.) Hรถhn. & Litsch.',
#   'species': 'Tomentella subfusca',
#   'speciesKey': 5239021,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5239021},
#  'NHMSYS0001716811': {'canonicalName': 'Anisoplia',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 96,
#   'family': 'Rutelidae',
#   'familyKey': 4425773,
#   'genus': 'Anisoplia',
#   'genusKey': 8104872,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Anisoplia Dejean, 1821',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 8104872},
#  'NHMSYS0019999941': {'canonicalName': 'Rhizophydium hyalobryi',
#   'class': 'Chytridiomycetes',
#   'classKey': 318,
#   'confidence': 100,
#   'family': 'Rhizophydiaceae',
#   'familyKey': 3814,
#   'genus': 'Rhizophydium',
#   'genusKey': 2627132,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Rhizophydiales',
#   'orderKey': 1117,
#   'phylum': 'Chytridiomycota',
#   'phylumKey': 94,
#   'rank': 'SPECIES',
#   'scientificName': 'Rhizophydium hyalobryi Canter',
#   'species': 'Rhizophydium hyalobryi',
#   'speciesKey': 3384477,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3384477},
#  'NHMSYS0020110551': {'canonicalName': 'Cotoneaster hurusawaianus',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 100,
#   'family': 'Rosaceae',
#   'familyKey': 5015,
#   'genus': 'Cotoneaster',
#   'genusKey': 3025563,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Rosales',
#   'orderKey': 691,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Cotoneaster hurusawaianus G. Klotz',
#   'species': 'Cotoneaster acutifolius',
#   'speciesKey': 3025770,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 3025930},
#  'NHMSYS0100000796': {'canonicalName': 'Brachiaria platyphylla',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 100,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Brachiaria',
#   'genusKey': 2704067,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Tracheophyta',
#   'phylumKey': 7707728,
#   'rank': 'SPECIES',
#   'scientificName': 'Brachiaria platyphylla (Munro ex C.Wright) Nash',
#   'species': 'Brachiaria platyphylla',
#   'speciesKey': 2705857,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2705857},
#  'NHMSYS0100002417': {'confidence': 100,
#   'matchType': 'NONE',
#   'synonym': False}}

# %% [markdown]
# ### Chunked version

# %% [markdown]
# Let's try it in chunks of around 100 requests in batches of 50000:

# %%
len(recorder_names)
# Out:
# 144135

# %%
import time

# %% [markdown]
# I made the following cells in raw-text to exclude them from running the whole sequence again when just running the notebook, the result of the sequence of runs is loaded as a variable: `recorder_matched` in the next code cell

# %% [raw]
# chunksize = 100
# batchstart = 0
# batchsize = 50000
#
# data_collect = {}
# for i in range(batchstart, batchstart + batchsize, chunksize):
#     current_case = recorder_names.iloc[i:i+chunksize, :]
#     names = current_case["scientificName"]
#     kingdoms = current_case["kingdom"]
#     inbo_idx = current_case["RECOMMENDED_TAXON_VERSION_KEY"]
#
#     temp = Collector()
#     with aiohttp.ClientSession() as client:
#         asyncio.get_event_loop().run_until_complete(asyncio.wait(
#                 [temp.fetch(client, name, kingdom, idx) for name, kingdom, idx in zip(names, kingdoms, inbo_idx)]))
#
#     #    if len(temp.data) < chunksize:
#     print(len(temp.data))
#     data_collect.update(temp.data)
#
# run_part = pd.DataFrame(data_collect).transpose()
# run_part.to_csv("".join(["recorder_", str(batchstart), "_till_", str(batchsize), ".csv"]))

# %% [raw]
# chunksize = 100
# batchstart = 50000
# batchsize = 50000
#
# data_collect = {}
# for i in range(batchstart, batchstart + batchsize, chunksize):
#     current_case = recorder_names.iloc[i:i+chunksize, :]
#     names = current_case["scientificName"]
#     kingdoms = current_case["kingdom"]
#     inbo_idx = current_case["RECOMMENDED_TAXON_VERSION_KEY"]
#
#     temp = Collector()
#     with aiohttp.ClientSession() as client:
#         asyncio.get_event_loop().run_until_complete(asyncio.wait(
#                 [temp.fetch(client, name, kingdom, idx) for name, kingdom, idx in zip(names, kingdoms, inbo_idx)]))
#
#     #    if len(temp.data) < chunksize:
#     print(len(temp.data))
#     data_collect.update(temp.data)
#
# run_part = pd.DataFrame(data_collect).transpose()
# run_part.to_csv("".join(["recorder_", str(batchstart), "_till_", str(batchsize), ".csv"]))

# %% [raw]
# chunksize = 100
# batchstart = 100000
# batchsize = 44136
#
# data_collect = {}
# for i in range(batchstart, batchstart + batchsize, chunksize):
#     current_case = recorder_names.iloc[i:i+chunksize, :]
#     names = current_case["scientificName"]
#     kingdoms = current_case["kingdom"]
#     inbo_idx = current_case["RECOMMENDED_TAXON_VERSION_KEY"]
#
#     temp = Collector()
#     with aiohttp.ClientSession() as client:
#         asyncio.get_event_loop().run_until_complete(asyncio.wait(
#                 [temp.fetch(client, name, kingdom, idx) for name, kingdom, idx in zip(names, kingdoms, inbo_idx)]))
#
#     #    if len(temp.data) < chunksize:
#     print(len(temp.data))
#     data_collect.update(temp.data)
#
# run_part = pd.DataFrame(data_collect).transpose()
# run_part.to_csv("".join(["recorder_", str(batchstart), "_till_", str(batchsize), ".csv"]))

# %% [raw]
# Combining the three batches:

# %% [raw]
# results1 = pd.read_csv("recorder_0_till_50000.csv", dtype=object)
# results2 = pd.read_csv("recorder_50000_till_50000.csv", dtype=object)
# results3 = pd.read_csv("recorder_100000_till_44136.csv", dtype=object)

# %% [raw]
# result = pd.concat((results1, results2, results3))

# %% [raw]
# len(result)

# %% [markdown]
# Not missing that much requests anymore, since we're less than 144135 requests

# %% [markdown]
# #### Retrying the missing requests

# %% [markdown]
# Some requests just went wrong, let's redo this set of around 100 failures..

# %% [raw]
# compare = pd.merge(recorder_names, result, left_on="RECOMMENDED_TAXON_VERSION_KEY", right_on="Unnamed: 0", how='left')

# %% [raw]
# toredo = compare[compare["Unnamed: 0"].isnull()][["RECOMMENDED_TAXON_VERSION_KEY", "scientificName_x", "kingdom_x"]]

# %% [raw]
# toredo.head(10)

# %% [raw]
# support_redo = {}
# for idx, row in toredo.iterrows():
#     support_redo[row["RECOMMENDED_TAXON_VERSION_KEY"]] = extract_gbif_species_names_info(row["scientificName_x"], row["kingdom_x"])

# %% [raw]
# redo_df = pd.DataFrame(support_redo).transpose()

# %% [raw]
# redo_df = redo_df.reset_index()
# redo_df = redo_df.rename(columns={"index" : "Unnamed: 0"})

# %% [raw]
# recorder_matched = pd.concat((redo_df, result))

# %%
# next section also added - here now reading: recorder_sql_unique_names_matched.csv is added to git
# however, the acceptedkey is added as well in the next section...
#recorder_matched.to_csv("recorder_sql_unique_names_matched.csv", dtype=object)
#recorder_matched = pd.read_csv("recorder_sql_unique_names_matched.csv", dtype=object)

# %%
recorder_matched = recorder_matched.set_index("Unnamed: 0")

# %%
recorder_matched
# Out:
#                 Unnamed: 0.1                    canonicalName  \
# Unnamed: 0
# 0           INBSYS0000005533           Cotoneaster villosulus
# 1           NBNSYS0000019326                              NaN
# 2           NBNSYS0000022430                 Leuctra hippopus
# 3           NBNSYS0200001885              Axonopus compressus
# 4           NHMSYS0001480349            Dasyscyphus relicinus
# 5           NHMSYS0001491558               Otidea phlebophora
# 6           NHMSYS0020110590              Taraxacum amarellum
# 0           BFN0017900000007              Hyloniscus riparius
# 1           BFN001790000000A                              NaN
# 2           BFN001790000000O                              NaN
# 3           BMSSYS0000000001            Abrothallus cetrariae
# 4           BMSSYS0000000008          Abrothallus welwitschii
# 5           BMSSYS0000000012              Absidia californica
# 6           BMSSYS0000000014              Absidia corymbifera
# 7           BMSSYS0000000018              Absidia heterospora
# 8           BMSSYS0000000024          Absidia spinosa spinosa
# 9           BMSSYS0000000039                    Acanthostigma
# 10          BMSSYS0000000043        Acanthostigma perpusillum
# 11          BMSSYS0000000050                              NaN
# 12          BMSSYS0000000072                              NaN
# 13          BMSSYS0000000085                 Achlya americana
# 14          BMSSYS0000000088                   Achlya bispora
# 15          BMSSYS0000000089               Achlya caroliniana
# 16          BMSSYS0000000093                Achlya flagellata
# 17          BMSSYS0000000094                 Achlya glomerata
# 18          BMSSYS0000000099                 Achlya oblongata
# 19          BMSSYS0000000102                 Achlya polyandra
# 20          BMSSYS0000000108               Achlya treleaseana
# 21          BMSSYS0000000122                         Acladium
# 22          BMSSYS0000000125                  Acladium fuscum
# ...                      ...                              ...
# 44099       NHMSYS0100001728  Helleborus viridis occidentalis
# 44100       NHMSYS0100001751           Hieracium peleterianum
# 44101       NHMSYS0100001776        Hordeum murinum leporinum
# 44102       NHMSYS0100001790              Hydrilla lithuanica
# 44103       NHMSYS0100001814             Inula oculus-christi
# 44104       NHMSYS0100001815                Iochroma australe
# 44105       NHMSYS0100001856          Juniperus communis nana
# 44106       NHMSYS0100001861                 Kalmia latifolia
# 44107       NHMSYS0100002013                   Medicago varia
# 44108       NHMSYS0100002053                              NaN
# 44109       NHMSYS0100002058     Minuartia hybrida tenuifolia
# 44110       NHMSYS0100002071                 Montia rivularis
# 44111       NHMSYS0100002096          Najas marina intermedia
# 44112       NHMSYS0100002100                              NaN
# 44113       NHMSYS0100002175             Ononis alopecuroides
# 44114       NHMSYS0100002418                              NaN
# 44115       NHMSYS0100002551                              NaN
# 44116       NHMSYS0100002653                              NaN
# 44117       NHMSYS0100002659        Ranunculus pseudofluitans
# 44118       NHMSYS0100002663     Rapistrum rugosum linnaeanum
# 44119       NHMSYS0100002709                              NaN
# 44120       NHMSYS0100002714                              NaN
# 44121       NHMSYS0100002719                              NaN
# 44122       NHMSYS0100002764                              NaN
# 44123       NHMSYS0100002873             Saxifraga paniculata
# 44124       NHMSYS0100002991                  Sisymbrium irio
# 44125       NHMSYS0100003052                              NaN
# 44126       NHMSYS0100003091                              NaN
# 44127       NHMSYS0100003177                      Ulmus minor
# 44128       NHMSYS0100003239      Watsonia borbonica ardernei
#
#                       class classKey confidence              family familyKey  \
# Unnamed: 0
# 0             Magnoliopsida      220        100            Rosaceae      5015
# 1                       NaN      NaN        100                 NaN       NaN
# 2                   Insecta      216        100          Leuctridae      2998
# 3                Liliopsida      196        100             Poaceae      3073
# 4             Leotiomycetes      179        100          Lachnaceae   3295205
# 5             Pezizomycetes      316        100      Pyronemataceae      4131
# 6             Magnoliopsida      220        100          Asteraceae      3065
# 0              Malacostraca      229        100      Trichoniscidae      5764
# 1                       NaN      NaN        100                 NaN       NaN
# 2                       NaN      NaN        100                 NaN       NaN
# 3                       NaN      NaN         99      Abrothallaceae   8401066
# 4                       NaN      NaN         99      Abrothallaceae   8401066
# 5                       NaN      NaN        100  Cunninghamellaceae      8275
# 6                       NaN      NaN        100     Lichtheimiaceae   3563119
# 7                       NaN      NaN        100  Cunninghamellaceae      8275
# 8                       NaN      NaN        100  Cunninghamellaceae      8275
# 9           Dothideomycetes      183         98        Tubeufiaceae      8316
# 10          Dothideomycetes      183        100        Tubeufiaceae      8316
# 11                      NaN      NaN         99                 NaN       NaN
# 12                      NaN      NaN         99                 NaN       NaN
# 13             Peronosporea  8179345        100     Saprolegniaceae      4789
# 14             Peronosporea  8179345        100     Saprolegniaceae      4789
# 15             Peronosporea  8179345        100     Saprolegniaceae      4789
# 16             Peronosporea  8179345        100     Saprolegniaceae      4789
# 17             Peronosporea  8179345        100     Saprolegniaceae      4789
# 18             Peronosporea  8179345        100     Saprolegniaceae      4789
# 19             Peronosporea  8179345        100     Saprolegniaceae      4789
# 20             Peronosporea  8179345        100     Saprolegniaceae      4789
# 21           Agaricomycetes      186         98   Botryobasidiaceae      4197
# 22           Agaricomycetes      186        100   Botryobasidiaceae      4197
# ...                     ...      ...        ...                 ...       ...
# 44099         Magnoliopsida      220        100       Ranunculaceae      2410
# 44100         Magnoliopsida      220        100          Asteraceae      3065
# 44101            Liliopsida      196         99             Poaceae      3073
# 44102            Liliopsida      196        100    Hydrocharitaceae      3721
# 44103         Magnoliopsida      220         97          Asteraceae      3065
# 44104         Magnoliopsida      220        100          Solanaceae      7717
# 44105             Pinopsida      194        100        Cupressaceae      8144
# 44106         Magnoliopsida      220        100           Ericaceae      2505
# 44107         Magnoliopsida      220        100            Fabaceae      5386
# 44108                   NaN      NaN        100                 NaN       NaN
# 44109         Magnoliopsida      220        100     Caryophyllaceae      2518
# 44110         Magnoliopsida      220         99          Montiaceae   4898338
# 44111            Liliopsida      196        100    Hydrocharitaceae      3721
# 44112                   NaN      NaN        100                 NaN       NaN
# 44113         Magnoliopsida      220         99            Fabaceae      5386
# 44114                   NaN      NaN        100                 NaN       NaN
# 44115                   NaN      NaN        100                 NaN       NaN
# 44116                   NaN      NaN        100                 NaN       NaN
# 44117         Magnoliopsida      220         99       Ranunculaceae      2410
# 44118         Magnoliopsida      220        100        Brassicaceae      3112
# 44119                   NaN      NaN        100                 NaN       NaN
# 44120                   NaN      NaN        100                 NaN       NaN
# 44121                   NaN      NaN        100                 NaN       NaN
# 44122                   NaN      NaN        100                 NaN       NaN
# 44123         Magnoliopsida      220         99       Saxifragaceae      2402
# 44124         Magnoliopsida      220         99        Brassicaceae      3112
# 44125                   NaN      NaN        100                 NaN       NaN
# 44126                   NaN      NaN        100                 NaN       NaN
# 44127         Magnoliopsida      220        100            Ulmaceae      2382
# 44128            Liliopsida      196        100           Iridaceae      7698
#
#                     genus genusKey    kingdom   ...    orderKey  \
# Unnamed: 0                                      ...
# 0             Cotoneaster  3025563    Plantae   ...         691
# 1                     NaN      NaN        NaN   ...         NaN
# 2                 Leuctra  2001760   Animalia   ...         787
# 3               Mesosetum  4113460    Plantae   ...        1369
# 4                 Lachnum  2581043      Fungi   ...        1052
# 5             Flavoscypha  2594209      Fungi   ...        1057
# 6               Taraxacum  8322495    Plantae   ...         414
# 0              Hyloniscus  2208506   Animalia   ...         643
# 1                     NaN      NaN        NaN   ...         NaN
# 2                     NaN      NaN        NaN   ...         NaN
# 3             Abrothallus  2584324      Fungi   ...     7621235
# 4             Abrothallus  2584324      Fungi   ...     7621235
# 5                 Absidia  2558224      Fungi   ...         749
# 6             Lichtheimia  2558353      Fungi   ...         749
# 7                 Absidia  2558224      Fungi   ...         749
# 8                 Absidia  2558224      Fungi   ...         749
# 9           Acanthostigma  2560760      Fungi   ...     7759254
# 10          Acanthostigma  2560760      Fungi   ...     7759254
# 11                    NaN      NaN        NaN   ...         NaN
# 12                    NaN      NaN        NaN   ...         NaN
# 13                 Achlya  3203100  Chromista   ...        1031
# 14                 Achlya  3203100  Chromista   ...        1031
# 15                 Achlya  3203100  Chromista   ...        1031
# 16                 Achlya  3203100  Chromista   ...        1031
# 17                 Achlya  3203100  Chromista   ...        1031
# 18                 Newbya  3203059  Chromista   ...        1031
# 19                 Newbya  3203059  Chromista   ...        1031
# 20                 Achlya  3203100  Chromista   ...        1031
# 21               Acladium  7241850      Fungi   ...        1300
# 22               Acladium  7241850      Fungi   ...        1300
# ...                   ...      ...        ...   ...         ...
# 44099          Helleborus  2741682    Plantae   ...         399
# 44100           Pilosella  8179194    Plantae   ...         414
# 44101             Hordeum  2706050    Plantae   ...        1369
# 44102            Hydrilla  2865997    Plantae   ...         551
# 44103               Inula  3148323    Plantae   ...         414
# 44104            Iochroma  6402978    Plantae   ...        1176
# 44105           Juniperus  2684359    Plantae   ...         640
# 44106              Kalmia  2882989    Plantae   ...        1353
# 44107            Lathyrus  2962244    Plantae   ...        1370
# 44108                 NaN      NaN        NaN   ...         NaN
# 44109            Sabulina  3085409    Plantae   ...         422
# 44110              Montia  3084779    Plantae   ...         422
# 44111               Najas  2865618    Plantae   ...         551
# 44112                 NaN      NaN        NaN   ...         NaN
# 44113          Astragalus  2933951    Plantae   ...        1370
# 44114                 NaN      NaN        NaN   ...         NaN
# 44115                 NaN      NaN        NaN   ...         NaN
# 44116                 NaN      NaN        NaN   ...         NaN
# 44117          Ranunculus  3033294    Plantae   ...         399
# 44118           Rapistrum  8306649    Plantae   ...     7225535
# 44119                 NaN      NaN        NaN   ...         NaN
# 44120                 NaN      NaN        NaN   ...         NaN
# 44121                 NaN      NaN        NaN   ...         NaN
# 44122                 NaN      NaN        NaN   ...         NaN
# 44123           Saxifraga  2987833    Plantae   ...     7219248
# 44124          Sisymbrium  3046735    Plantae   ...     7225535
# 44125                 NaN      NaN        NaN   ...         NaN
# 44126                 NaN      NaN        NaN   ...         NaN
# 44127               Ulmus  2984510    Plantae   ...         691
# 44128            Watsonia  2747139    Plantae   ...        1169
#
#                    phylum phylumKey        rank  \
# Unnamed: 0
# 0            Tracheophyta   7707728     SPECIES
# 1                     NaN       NaN         NaN
# 2              Arthropoda        54     SPECIES
# 3            Tracheophyta   7707728     SPECIES
# 4              Ascomycota        95     SPECIES
# 5              Ascomycota        95     SPECIES
# 6            Tracheophyta   7707728     SPECIES
# 0              Arthropoda        54     SPECIES
# 1                     NaN       NaN         NaN
# 2                     NaN       NaN         NaN
# 3              Ascomycota        95     SPECIES
# 4              Ascomycota        95     SPECIES
# 5              Zygomycota        96     SPECIES
# 6              Zygomycota        96     SPECIES
# 7              Zygomycota        96     SPECIES
# 8              Zygomycota        96     VARIETY
# 9              Ascomycota        95       GENUS
# 10             Ascomycota        95     SPECIES
# 11                    NaN       NaN         NaN
# 12                    NaN       NaN         NaN
# 13               Oomycota        32     SPECIES
# 14               Oomycota        32     SPECIES
# 15               Oomycota        32     SPECIES
# 16               Oomycota        32     SPECIES
# 17               Oomycota        32     SPECIES
# 18               Oomycota        32     SPECIES
# 19               Oomycota        32     SPECIES
# 20               Oomycota        32     SPECIES
# 21          Basidiomycota        34       GENUS
# 22          Basidiomycota        34     SPECIES
# ...                   ...       ...         ...
# 44099        Tracheophyta   7707728  SUBSPECIES
# 44100        Tracheophyta   7707728     SPECIES
# 44101        Tracheophyta   7707728  SUBSPECIES
# 44102        Tracheophyta   7707728     SPECIES
# 44103        Tracheophyta   7707728     SPECIES
# 44104        Tracheophyta   7707728     SPECIES
# 44105        Tracheophyta   7707728  SUBSPECIES
# 44106        Tracheophyta   7707728     SPECIES
# 44107        Tracheophyta   7707728     SPECIES
# 44108                 NaN       NaN         NaN
# 44109        Tracheophyta   7707728  SUBSPECIES
# 44110        Tracheophyta   7707728     SPECIES
# 44111        Tracheophyta   7707728  SUBSPECIES
# 44112                 NaN       NaN         NaN
# 44113        Tracheophyta   7707728     SPECIES
# 44114                 NaN       NaN         NaN
# 44115                 NaN       NaN         NaN
# 44116                 NaN       NaN         NaN
# 44117        Tracheophyta   7707728     SPECIES
# 44118        Tracheophyta   7707728  SUBSPECIES
# 44119                 NaN       NaN         NaN
# 44120                 NaN       NaN         NaN
# 44121                 NaN       NaN         NaN
# 44122                 NaN       NaN         NaN
# 44123        Tracheophyta   7707728     SPECIES
# 44124        Tracheophyta   7707728     SPECIES
# 44125                 NaN       NaN         NaN
# 44126                 NaN       NaN         NaN
# 44127        Tracheophyta   7707728     SPECIES
# 44128        Tracheophyta   7707728  SUBSPECIES
#
#                                                scientificName  \
# Unnamed: 0
# 0           Cotoneaster villosulus (Rehder & E.H. Wilson) ...
# 1                                                         NaN
# 2                               Leuctra hippopus Kempny, 1899
# 3                          Axonopus compressus (Sw.) P.Beauv.
# 4                           Dasyscyphus relicinus (Fr.) Boud.
# 5             Otidea phlebophora (Berk. & Broome) Sacc., 1889
# 6                    Taraxacum amarellum Kirschner & Štepánek
# 0                            Hyloniscus riparius (Koch, 1838)
# 1                                                         NaN
# 2                                                         NaN
# 3                        Abrothallus cetrariae I. Kotte, 1909
# 4                         Abrothallus welwitschii Mont., 1856
# 5             Absidia californica J.J. Ellis & Hesselt., 1965
# 6            Absidia corymbifera (Cohn) Sacc. & Trotter, 1912
# 7                           Absidia heterospora Y. Ling, 1930
# 8                   Absidia spinosa var. spinosa Lendn., 1907
# 9                              Acanthostigma De Notaris, 1863
# 10                    Acanthostigma perpusillum De Not., 1863
# 11                                                        NaN
# 12                                                        NaN
# 13                            Achlya americana Humphrey, 1893
# 14                       Achlya bispora (Couch) Langsam, 1986
# 15                             Achlya caroliniana Coker, 1910
# 16                              Achlya flagellata Coker, 1923
# 17                               Achlya glomerata Coker, 1912
# 18                             Achlya oblongata de Bary, 1888
# 19                            Achlya polyandra Hildebr., 1867
# 20               Achlya treleaseana (Humphrey) Kauffman, 1906
# 21                                        Acladium Link, 1809
# 22                                Acladium fuscum anon. ined.
# ...                                                       ...
# 44099       Helleborus viridis subsp. occidentalis (Reuter...
# 44100                           Hieracium peleterianum MĂŠrat
# 44101         Hordeum murinum subsp. leporinum (Link) Arcang.
# 44102                       Hydrilla lithuanica (Rchb.) Dandy
# 44103                                 Inula oculus-christi L.
# 44104                               Iochroma australe Griseb.
# 44105            Juniperus communis subsp. nana (Willd.) Syme
# 44106                                     Kalmia latifolia L.
# 44107                                   Medicago varia Martyn
# 44108                                                     NaN
# 44109       Minuartia hybrida subsp. tenuifolia (L.) M. Ke...
# 44110                          Montia rivularis C. C. Correll
# 44111       Najas marina subsp. intermedia (Wolfg. ex Gors...
# 44112                                                     NaN
# 44113                                 Ononis alopecuroides L.
# 44114                                                     NaN
# 44115                                                     NaN
# 44116                                                     NaN
# 44117              Ranunculus pseudofluitans Newbould ex Syme
# 44118       Rapistrum rugosum subsp. linnaeanum Rouy & Fou...
# 44119                                                     NaN
# 44120                                                     NaN
# 44121                                                     NaN
# 44122                                                     NaN
# 44123                               Saxifraga paniculata Cav.
# 44124                                      Sisymbrium irio L.
# 44125                                                     NaN
# 44126                                                     NaN
# 44127                                       Ulmus minor Mill.
# 44128       Watsonia borbonica subsp. ardernei (Sander) Go...
#
#                               species speciesKey    status synonym usageKey
# Unnamed: 0
# 0             Cotoneaster acutifolius    3025770   SYNONYM    True  3025564
# 1                                 NaN        NaN       NaN   False      NaN
# 2                    Leuctra hippopus    2001976  ACCEPTED   False  2001976
# 3                Mesosetum compressum    4114391   SYNONYM    True  2705924
# 4                   Lachnum relicinum    3489190   SYNONYM    True  3281874
# 5             Flavoscypha phlebophora    2594210   SYNONYM    True  2594211
# 6                 Taraxacum amarellum    5699378  DOUBTFUL   False  5699378
# 0                 Hyloniscus riparius    2208537  ACCEPTED   False  2208537
# 1                                 NaN        NaN       NaN   False      NaN
# 2                                 NaN        NaN       NaN   False      NaN
# 3               Abrothallus cetrariae    7824496  ACCEPTED   False  7824496
# 4             Abrothallus welwitschii    2592363  ACCEPTED   False  2592363
# 5                 Absidia californica    5250609  ACCEPTED   False  5250609
# 6             Lichtheimia corymbifera    2558326   SYNONYM    True  5250325
# 7                 Absidia heterospora    5250620  ACCEPTED   False  5250620
# 8                     Absidia spinosa    3385789   SYNONYM    True  7073718
# 9                                 NaN        NaN  ACCEPTED   False  2560760
# 10          Acanthostigma perpusillum    2613808  ACCEPTED   False  2613808
# 11                                NaN        NaN       NaN   False      NaN
# 12                                NaN        NaN       NaN   False      NaN
# 13                   Achlya americana    5424187  ACCEPTED   False  5424187
# 14                     Achlya bispora    5424201  ACCEPTED   False  5424201
# 15                 Achlya caroliniana    5424208  ACCEPTED   False  5424208
# 16                  Achlya flagellata    5424200  ACCEPTED   False  5424200
# 17                   Achlya glomerata    5424190  ACCEPTED   False  5424190
# 18                   Newbya oblongata    3203081   SYNONYM    True  5424173
# 19                   Newbya polyandra    3203079   SYNONYM    True  5424171
# 20                   Achlya androgyna    5424210   SYNONYM    True  5424212
# 21                                NaN        NaN  ACCEPTED   False  7241850
# 22                    Acladium fuscum    3367484  ACCEPTED   False  3367484
# ...                               ...        ...       ...     ...      ...
# 44099              Helleborus viridis    3033108  ACCEPTED   False  5828642
# 44100           Pilosella peleteriana    3123717   SYNONYM    True  3123718
# 44101                 Hordeum murinum    7886346  ACCEPTED   False  4270548
# 44102           Hydrilla verticillata    5329570   SYNONYM    True  5329590
# 44103            Inula oculus-christi    3148356  DOUBTFUL   False  3148356
# 44104               Iochroma australe    3802419  ACCEPTED   False  3802419
# 44105              Juniperus communis    2684709   SYNONYM    True  2684760
# 44106                Kalmia latifolia    2883005  ACCEPTED   False  2883005
# 44107                Lathyrus sativus    5356488   SYNONYM    True  2965331
# 44108                             NaN        NaN       NaN   False      NaN
# 44109             Sabulina tenuifolia    8039191   SYNONYM    True  3812798
# 44110                Montia rivularis    7789946  ACCEPTED   False  7789946
# 44111                    Najas marina    5329324   SYNONYM    True  7908614
# 44112                             NaN        NaN       NaN   False      NaN
# 44113        Astragalus alopecuroides    5343178   SYNONYM    True  2977222
# 44114                             NaN        NaN       NaN   False      NaN
# 44115                             NaN        NaN       NaN   False      NaN
# 44116                             NaN        NaN       NaN   False      NaN
# 44117         Ranunculus penicillatus    7278019   SYNONYM    True  3928002
# 44118               Rapistrum rugosum    5373368   SYNONYM    True  5373375
# 44119                             NaN        NaN       NaN   False      NaN
# 44120                             NaN        NaN       NaN   False      NaN
# 44121                             NaN        NaN       NaN   False      NaN
# 44122                             NaN        NaN       NaN   False      NaN
# 44123            Saxifraga paniculata    7885434  ACCEPTED   False  7885434
# 44124                 Sisymbrium irio    3046851  ACCEPTED   False  3046851
# 44125                             NaN        NaN       NaN   False      NaN
# 44126                             NaN        NaN       NaN   False      NaN
# 44127                     Ulmus minor    5361865  ACCEPTED   False  5361865
# 44128              Watsonia borbonica    5297820  ACCEPTED   False  5297828
#
# [144135 rows x 24 columns]

# %% [markdown]
# ## Combined matched profile of recorder names

# %% [markdown]
# Some information:

# %%
recorder_matched.columns
# Out:
# Index(['Unnamed: 0.1', 'canonicalName', 'class', 'classKey', 'confidence',
#        'family', 'familyKey', 'genus', 'genusKey', 'kingdom', 'kingdomKey',
#        'matchType', 'note', 'order', 'orderKey', 'phylum', 'phylumKey', 'rank',
#        'scientificName', 'species', 'speciesKey', 'status', 'synonym',
#        'usageKey'],
#       dtype='object')

# %%
sum(recorder_matched["status"].isnull())
# Out:
# 31980

# %% [markdown]
# So, a large set of None-matches...

# %%
recorder_matched.groupby(("matchType")).count()["canonicalName"]
# Out:
# matchType
# EXACT    112155
# NONE          0
# Name: canonicalName, dtype: int64

# %%
recorder_matched.groupby(("status")).count()["canonicalName"]
# Out:
# status
# ACCEPTED    96067
# DOUBTFUL     2481
# SYNONYM     13607
# Name: canonicalName, dtype: int64

# %% [markdown]
# #### Different reasons for failed answer in the note:

# %% [markdown]
# *Multiple equal matches for...* added by the name

# %%
sum(recorder_matched["note"].str.contains("too little").dropna())
# Out:
# 19818

# %% [markdown]
# *No match because of too little confidence*

# %%
sum(recorder_matched["note"].str.contains("Multiple equal matches").dropna())
# Out:
# 988

# %% [markdown]
# *N synonym homonyms* (with N = 2, 3,...) -> When SYNONYM is found

# %%
sum(recorder_matched["note"].str.contains("synonym homonyms").dropna())
# Out:
# 1344

# %%
recorder_matched.columns
# Out:
# Index(['Unnamed: 0.1', 'canonicalName', 'class', 'classKey', 'confidence',
#        'family', 'familyKey', 'genus', 'genusKey', 'kingdom', 'kingdomKey',
#        'matchType', 'note', 'order', 'orderKey', 'phylum', 'phylumKey', 'rank',
#        'scientificName', 'species', 'speciesKey', 'status', 'synonym',
#        'usageKey'],
#       dtype='object')

# %% [markdown]
# ### getting the acceptedKey when the status is not accepted but SYNONYM

# %%
recorder_matched["acceptedKey"] = recorder_matched["usageKey"]
recorder_matched["acceptedScientificName"] = recorder_matched["scientificName"]

# %%
for idx, row in recorder_matched.iterrows():
    if row["synonym"] == 'True':
        if row["acceptedKey"] == row["usageKey"]: 
            #print(row["usageKey"], row["acceptedKey"]) 
            base_string = "http://api.gbif.org/v1/species/"
            request = ''.join((base_string, str(int(row["usageKey"]))))
            message = requests.get(_escape_spaces(request)).json()
            try:
                row["acceptedKey"] = message["acceptedKey"]
                row["acceptedScientificName"] = message["accepted"]
            except:
                print(message)
                row["acceptedKey"] = None
                row["acceptedScientificName"] = None

# %%
recorder_matched = recorder_matched.reset_index()
recorder_matched = recorder_matched.drop("Unnamed: 0", axis=1)
recorder_matched = recorder_matched.set_index("Unnamed: 0.1")

# %% [markdown]
# ## READ (redo) or LOAD MATCHED AND ACCEPTEDKEY:

# %%
recorder_matched.to_csv("recorder_sql_unique_names_matched.csv", dtype=object)
#recorder_matched = pd.read_csv("recorder_sql_unique_names_matched.csv", dtype=object)

# %%
recorder_matched = recorder_matched.drop("Unnamed: 0", axis=1)

# %%
#recorder_matched = recorder_matched.reset_index().rename(columns={"Unnamed: 0.1":"NBN_index"})

# %%
len(recorder_matched)
# Out:
# 144135

# %% [markdown]
# that are seperately defined in recorder are linke to the same `acceptedKey` in GBIF

# %% [markdown]
# **Need to be adjusted from here, as defined in [ISSUE #47](https://github.com/inbo/invasive-t0-occurrences/issues/47):**

# %% [markdown]
# ##  Species list to report on defined by Tim/Sander

# %% [markdown]
# Read species list:

# %%
invasive_species = pd.read_csv("../../species-list/species-list.tsv", delimiter="\t", dtype=object)

# %%
len(invasive_species)
# Out:
# 152

# %%
invasive_species.head()
# Out:
#   index                         name   kingdom      euConcernStatus  \
# 0     0                 Acer negundo   Plantae  under consideration
# 1     1         Alopochen aegyptiaca  Animalia  under consideration
# 2     2  Alternanthera philoxeroides   Plantae  under consideration
# 3     3               Ameiurus melas  Animalia  under consideration
# 4     4            Asclepias syriaca   Plantae  under consideration
#
#   gbifapi_usageKey                       gbifapi_scientificName  \
# 0          3189866                              Acer negundo L.
# 1          2498252        Alopochen aegyptiaca (Linnaeus, 1766)
# 2          3084923  Alternanthera philoxeroides (Mart.) Griseb.
# 3          2340977            Ameiurus melas (Rafinesque, 1820)
# 4          3170247                         Asclepias syriaca L.
#
#          gbifapi_canonicalName gbifapi_status gbifapi_rank gbifapi_matchType  \
# 0                 Acer negundo       ACCEPTED      SPECIES             EXACT
# 1         Alopochen aegyptiaca       ACCEPTED      SPECIES             EXACT
# 2  Alternanthera philoxeroides       ACCEPTED      SPECIES             EXACT
# 3               Ameiurus melas       ACCEPTED      SPECIES             EXACT
# 4            Asclepias syriaca       ACCEPTED      SPECIES             EXACT
#
#   gbifapi_confidence gbifapi_acceptedKey  \
# 0                100             3189866
# 1                100             2498252
# 2                100             3084923
# 3                100             2340977
# 4                 99             3170247
#
#                 gbifapi_acceptedScientificName        nbnTaxonID
# 0                              Acer negundo L.  NBNSYS0000014604
# 1        Alopochen aegyptiaca (Linnaeus, 1766)  NHMSYS0001689380
# 2  Alternanthera philoxeroides (Mart.) Griseb.               NaN
# 3            Ameiurus melas (Rafinesque, 1820)  NHMSYS0000544615
# 4                         Asclepias syriaca L.  INBSYS0000005932

# %%
recorder_matched.columns
# Out:
# Index(['NBN_index', 'canonicalName', 'class', 'classKey', 'confidence',
#        'family', 'familyKey', 'genus', 'genusKey', 'kingdom', 'kingdomKey',
#        'matchType', 'note', 'order', 'orderKey', 'phylum', 'phylumKey', 'rank',
#        'scientificName', 'species', 'speciesKey', 'status', 'synonym',
#        'usageKey', 'acceptedKey', 'acceptedScientificName'],
#       dtype='object')

# %% [raw]
# invasive_species_key = invasive_species[~invasive_species["gbifapi_acceptedKey"].isnull()][['name', 'kingdom',
#                                                                                             'gbifapi_acceptedKey',
#                                                                                             'gbifapi_acceptedScientificName']]

# %%
invasive_species_key = invasive_species[['name', 'kingdom', 
                                         'gbifapi_acceptedKey', 
                                         'gbifapi_acceptedScientificName']]

# %%
recorder_matched_key = recorder_matched[~recorder_matched["acceptedKey"].isnull()][['NBN_index', 
                                                                                    'acceptedKey', 
                                                                                    'status', 
                                                                                    'confidence']]

# %%
combination = pd.merge(invasive_species_key, 
                recorder_matched_key, 
                how='left',
                left_on="gbifapi_acceptedKey", 
                right_on="acceptedKey",
                suffixes=('_species', '_recorder'))

# %%
combination
# Out:
#                             name    kingdom gbifapi_acceptedKey  \
# 0                   Acer negundo    Plantae             3189866
# 1           Alopochen aegyptiaca   Animalia             2498252
# 2    Alternanthera philoxeroides    Plantae             3084923
# 3                 Ameiurus melas   Animalia             2340977
# 4              Asclepias syriaca    Plantae             3170247
# 5        Symphyotrichum salignum    Plantae             3151811
# 6          Baccharis halimifolia    Plantae                 NaN
# 7                    Bison bison   Animalia             2441176
# 8            Cabomba caroliniana    Plantae             2882443
# 9        Callosciurus erythraeus   Animalia             2437394
# 10               Caprella mutica   Animalia             5178057
# 11             Castor canadensis   Animalia             2439838
# 12             Castor canadensis   Animalia             2439838
# 13         Celastrus orbiculatus    Plantae             8104460
# 14              Corvus splendens   Animalia             2482499
# 15          Cotoneaster ambiguus    Plantae             3025858
# 16         Cotoneaster ascendens    Plantae             3026024
# 17         Cotoneaster boisianus    Plantae             3026295
# 18          Cotoneaster bullatus    Plantae             3026294
# 19        Cotoneaster conspicuus    Plantae             3025875
# 20         Cotoneaster coriaceus    Plantae             3026035
# 21           Cotoneaster dammeri    Plantae             3026049
# 22           Cotoneaster dammeri    Plantae             3026049
# 23        Cotoneaster dielsianus    Plantae             3025896
# 24        Cotoneaster dielsianus    Plantae             3025896
# 25        Cotoneaster dielsianus    Plantae             3025896
# 26        Cotoneaster dielsianus    Plantae             3025896
# 27       Cotoneaster divaricatus    Plantae             3026334
# 28         Cotoneaster fangianus    Plantae             3025932
# 29        Cotoneaster franchetii    Plantae             3026162
# ..                           ...        ...                 ...
# 194                Rapana venosa   Animalia             4363583
# 195         Sagittaria latifolia    Plantae             5328909
# 196          Sarracenia purpurea    Plantae             5421389
# 197            Sargassum muticum  Eukaryota             3197314
# 198         Sciurus carolinensis   Animalia             5219681
# 199         Sciurus carolinensis   Animalia             5219681
# 200                Sciurus niger   Animalia             5219683
# 201             Sicyos angulatus    Plantae             2874655
# 202        Solanum eleagnifolium    Plantae             7299960
# 203        Euthamia graminifolia    Plantae             3092782
# 204        Euthamia graminifolia    Plantae             3092782
# 205           Spartina pectinata    Plantae             5290030
# 206           Spartina pectinata    Plantae             5290030
# 207           Spartina pectinata    Plantae             5290030
# 208          Spartina townsendii    Plantae             5290034
# 209          Spartina townsendii    Plantae             5290034
# 210          Spartina townsendii    Plantae             5290034
# 211          Spiraea salicifolia    Plantae             3026454
# 212          Spiraea salicifolia    Plantae             3026454
# 213            Spiraea tomentosa    Plantae             3026819
# 214            Spiraea tomentosa    Plantae             3026819
# 215            Spiraea tomentosa    Plantae             3026819
# 216            Spiraea tomentosa    Plantae             3026819
# 217    Spiraea pseudosalicifolia    Plantae             3026444
# 218             Tamias sibiricus   Animalia             2437450
# 219     Threskiornis aethiopicus   Animalia             2480764
# 220            Trachemys scripta   Animalia             2443002
# 221            Trachemys scripta   Animalia             2443002
# 222         Vallisneria spiralis    Plantae             2865526
# 223               Vespa velutina   Animalia             1311477
#
#                         gbifapi_acceptedScientificName         NBN_index  \
# 0                                      Acer negundo L.  NBNSYS0000014604
# 1                Alopochen aegyptiaca (Linnaeus, 1766)  NHMSYS0001689380
# 2          Alternanthera philoxeroides (Mart.) Griseb.               NaN
# 3                    Ameiurus melas (Rafinesque, 1820)  NHMSYS0000544615
# 4                                 Asclepias syriaca L.  INBSYS0000005932
# 5           Symphyotrichum salignum (Willd.) G.L.Nesom               NaN
# 6                                                  NaN               NaN
# 7                         Bison bison (Linnaeus, 1758)               NaN
# 8                          Cabomba caroliniana A. Gray  NHMSYS0000456744
# 9               Callosciurus erythraeus (Pallas, 1779)  INBSYS0000012711
# 10                       Caprella mutica Schurin, 1935  INBSYS0000046323
# 11                        Castor canadensis Kuhl, 1820  INBSYS0000012718
# 12                        Castor canadensis Kuhl, 1820  INBSYS0000032589
# 13    Celastrus orbiculatus C.P. Thunberg ex A. Murray  NHMSYS0100000968
# 14                     Corvus splendens Vieillot, 1817               NaN
# 15            Cotoneaster ambiguus Rehd. & E.H. Wilson  NHMSYS0000457622
# 16             Cotoneaster ascendens Flinck & B. Hylmö  NHMSYS0000457556
# 17   Cotoneaster bullatus var. floribundus (Stapf) ...  NBNSYS0100002625
# 18           Cotoneaster bullatus Bois in Bilm. & Bois  NBNSYS0000004710
# 19   Cotoneaster conspicuus H. F. Comber ex C. Marq...  NHMSYS0000457572
# 20                       Cotoneaster coriaceus Franch.  NHMSYS0000457601
# 21                   Cotoneaster dammeri C.K. Schneid.  NHMSYS0000457575
# 22                   Cotoneaster dammeri C.K. Schneid.  INBSYS0000011373
# 23                    Cotoneaster dielsianus E. Pritz.  NBNSYS0000014211
# 24                    Cotoneaster dielsianus E. Pritz.  NHMSYS0000457576
# 25                    Cotoneaster dielsianus E. Pritz.  INBSYS0000005539
# 26                    Cotoneaster dielsianus E. Pritz.  NBNSYS0100002637
# 27         Cotoneaster divaricatus Rehd. & E.H. Wilson  NBNSYS0000014035
# 28                       Cotoneaster fangianus T.T. Yu  NBNSYS0100002626
# 29                       Cotoneaster franchetii Boiss.  NBNSYS0000014170
# ..                                                 ...               ...
# 194                 Rapana venosa (Valenciennes, 1846)  INBSYS0000032669
# 195                        Sagittaria latifolia Willd.  NBNSYS0000002106
# 196                             Sarracenia purpurea L.  NBNSYS0000003523
# 197           Sargassum muticum (Yendo) Fensholt, 1955  NBNSYS0000188809
# 198        Sciurus (Sciurus) carolinensis Gmelin, 1788  NBNSYS0000005109
# 199        Sciurus (Sciurus) carolinensis Gmelin, 1788  NHMSYS0000332764
# 200             Sciurus (Sciurus) niger Linnaeus, 1758               NaN
# 201                                Sicyos angulatus L.  NBNSYS0000034270
# 202                              Solanum eleagnifolium  NBNSYS0200003195
# 203                   Euthamia graminifolia (L.) Nutt.  INBSYS0000005315
# 204                   Euthamia graminifolia (L.) Nutt.  NBNSYS0000004420
# 205                    Spartina pectinata Bosc ex Link  NBNSYS0000014303
# 206                    Spartina pectinata Bosc ex Link  NHMSYS0000463858
# 207                    Spartina pectinata Bosc ex Link  INBSYS0000009805
# 208            Spartina townsendii H.Groves & J.Groves  INBSYS0000003939
# 209            Spartina townsendii H.Groves & J.Groves  NBNSYS0000002679
# 210            Spartina townsendii H.Groves & J.Groves  NHMSYS0000463860
# 211                             Spiraea salicifolia L.  NHMSYS0000463917
# 212                             Spiraea salicifolia L.  NBNSYS0000003313
# 213                               Spiraea tomentosa L.  NHMSYS0000463792
# 214                               Spiraea tomentosa L.  INBSYS0000003949
# 215                               Spiraea tomentosa L.  NBNSYS0000014018
# 216                               Spiraea tomentosa L.  NBNSYS0000014176
# 217              Spiraea ×pseudosalicifolia Silverside  INBSYS0000003921
# 218        Tamias (Eutamias) sibiricus (Laxmann, 1769)  INBSYS0000012543
# 219            Threskiornis aethiopicus (Latham, 1790)  NHMSYS0000534047
# 220                   Trachemys scripta Schoepff, 1792  NHMSYS0000080227
# 221                   Trachemys scripta Schoepff, 1792  INBSYS0000012414
# 222                            Vallisneria spiralis L.  NBNSYS0000002118
# 223                    Vespa velutina Lepeletier, 1836               NaN
#
#     acceptedKey    status confidence
# 0       3189866  ACCEPTED        100
# 1       2498252   SYNONYM        100
# 2           NaN       NaN        NaN
# 3       2340977  ACCEPTED        100
# 4       3170247  ACCEPTED         99
# 5           NaN       NaN        NaN
# 6           NaN       NaN        NaN
# 7           NaN       NaN        NaN
# 8       2882443  ACCEPTED        100
# 9       2437394  ACCEPTED        100
# 10      5178057  ACCEPTED        100
# 11      2439838  ACCEPTED        100
# 12      2439838  ACCEPTED        100
# 13      8104460  ACCEPTED         99
# 14          NaN       NaN        NaN
# 15      3025858   SYNONYM        100
# 16      3026024  ACCEPTED        100
# 17      3026295   SYNONYM        100
# 18      3026294  ACCEPTED        100
# 19      3025875  ACCEPTED         99
# 20      3026035   SYNONYM        100
# 21      3026049  ACCEPTED        100
# 22      3026049  ACCEPTED        100
# 23      3025896  ACCEPTED         99
# 24      3025896  ACCEPTED         99
# 25      3025896  ACCEPTED         99
# 26      3025896   SYNONYM        100
# 27      3026334  ACCEPTED        100
# 28      3025932  ACCEPTED        100
# 29      3026162   SYNONYM        100
# ..          ...       ...        ...
# 194     4363583  ACCEPTED        100
# 195     5328909  ACCEPTED        100
# 196     5421389  ACCEPTED         99
# 197     3197314  ACCEPTED         95
# 198     5219681  ACCEPTED        100
# 199     5219681  ACCEPTED        100
# 200         NaN       NaN        NaN
# 201     2874655  ACCEPTED         99
# 202     7299960  ACCEPTED        100
# 203     3092782   SYNONYM         98
# 204     3092782   SYNONYM         98
# 205     5290030  ACCEPTED        100
# 206     5290030  ACCEPTED        100
# 207     5290030  ACCEPTED        100
# 208     5290034  ACCEPTED        100
# 209     5290034  ACCEPTED        100
# 210     5290034  ACCEPTED        100
# 211     3026454  ACCEPTED         99
# 212     3026454  ACCEPTED         99
# 213     3026819   SYNONYM        100
# 214     3026819   SYNONYM        100
# 215     3026819   SYNONYM        100
# 216     3026819  ACCEPTED         99
# 217     3026444  ACCEPTED         88
# 218     2437450  ACCEPTED        100
# 219     2480764  ACCEPTED        100
# 220     2443002  ACCEPTED         99
# 221     2443002  ACCEPTED         99
# 222     2865526  ACCEPTED        100
# 223         NaN       NaN        NaN
#
# [224 rows x 8 columns]

# %%
species_info_recorder_matches = pd.merge(combination, recorder_names, how='left', left_on="NBN_index", 
                                         right_on="RECOMMENDED_TAXON_VERSION_KEY",
                                         suffixes=('_x', '_recorder'))

# %%
species_info_recorder_matches = species_info_recorder_matches.drop(["RECOMMENDED_TAXON_VERSION_KEY", 
                                                                    "acceptedKey", "kingdom_recorder"],axis=1)

# %%
species_info_recorder_matches = species_info_recorder_matches.rename(columns={"kingdom_x":"kingdom", 
                                              "status":"NBN_status",
                                              "confidence":"NBN_confidence",
                                              "scientificName":"NBN_scientificName",
                                              "TAXON_GROUP_NAME":"NBN_taxon_group_info"
                                             })

# %%
species_info_recorder_matches.dtypes
# Out:
# name                              object
# kingdom                           object
# gbifapi_acceptedKey               object
# gbifapi_acceptedScientificName    object
# NBN_index                         object
# NBN_status                        object
# NBN_confidence                    object
# NBN_scientificName                object
# NBN_taxon_group_info              object
# dtype: object

# %%
species_info_recorder_matches
# Out:
#                             name    kingdom gbifapi_acceptedKey  \
# 0                   Acer negundo    Plantae             3189866
# 1           Alopochen aegyptiaca   Animalia             2498252
# 2    Alternanthera philoxeroides    Plantae             3084923
# 3                 Ameiurus melas   Animalia             2340977
# 4              Asclepias syriaca    Plantae             3170247
# 5        Symphyotrichum salignum    Plantae             3151811
# 6          Baccharis halimifolia    Plantae                 NaN
# 7                    Bison bison   Animalia             2441176
# 8            Cabomba caroliniana    Plantae             2882443
# 9        Callosciurus erythraeus   Animalia             2437394
# 10               Caprella mutica   Animalia             5178057
# 11             Castor canadensis   Animalia             2439838
# 12             Castor canadensis   Animalia             2439838
# 13         Celastrus orbiculatus    Plantae             8104460
# 14              Corvus splendens   Animalia             2482499
# 15          Cotoneaster ambiguus    Plantae             3025858
# 16         Cotoneaster ascendens    Plantae             3026024
# 17         Cotoneaster boisianus    Plantae             3026295
# 18          Cotoneaster bullatus    Plantae             3026294
# 19        Cotoneaster conspicuus    Plantae             3025875
# 20         Cotoneaster coriaceus    Plantae             3026035
# 21           Cotoneaster dammeri    Plantae             3026049
# 22           Cotoneaster dammeri    Plantae             3026049
# 23        Cotoneaster dielsianus    Plantae             3025896
# 24        Cotoneaster dielsianus    Plantae             3025896
# 25        Cotoneaster dielsianus    Plantae             3025896
# 26        Cotoneaster dielsianus    Plantae             3025896
# 27       Cotoneaster divaricatus    Plantae             3026334
# 28         Cotoneaster fangianus    Plantae             3025932
# 29        Cotoneaster franchetii    Plantae             3026162
# ..                           ...        ...                 ...
# 194                Rapana venosa   Animalia             4363583
# 195         Sagittaria latifolia    Plantae             5328909
# 196          Sarracenia purpurea    Plantae             5421389
# 197            Sargassum muticum  Eukaryota             3197314
# 198         Sciurus carolinensis   Animalia             5219681
# 199         Sciurus carolinensis   Animalia             5219681
# 200                Sciurus niger   Animalia             5219683
# 201             Sicyos angulatus    Plantae             2874655
# 202        Solanum eleagnifolium    Plantae             7299960
# 203        Euthamia graminifolia    Plantae             3092782
# 204        Euthamia graminifolia    Plantae             3092782
# 205           Spartina pectinata    Plantae             5290030
# 206           Spartina pectinata    Plantae             5290030
# 207           Spartina pectinata    Plantae             5290030
# 208          Spartina townsendii    Plantae             5290034
# 209          Spartina townsendii    Plantae             5290034
# 210          Spartina townsendii    Plantae             5290034
# 211          Spiraea salicifolia    Plantae             3026454
# 212          Spiraea salicifolia    Plantae             3026454
# 213            Spiraea tomentosa    Plantae             3026819
# 214            Spiraea tomentosa    Plantae             3026819
# 215            Spiraea tomentosa    Plantae             3026819
# 216            Spiraea tomentosa    Plantae             3026819
# 217    Spiraea pseudosalicifolia    Plantae             3026444
# 218             Tamias sibiricus   Animalia             2437450
# 219     Threskiornis aethiopicus   Animalia             2480764
# 220            Trachemys scripta   Animalia             2443002
# 221            Trachemys scripta   Animalia             2443002
# 222         Vallisneria spiralis    Plantae             2865526
# 223               Vespa velutina   Animalia             1311477
#
#                         gbifapi_acceptedScientificName         NBN_index  \
# 0                                      Acer negundo L.  NBNSYS0000014604
# 1                Alopochen aegyptiaca (Linnaeus, 1766)  NHMSYS0001689380
# 2          Alternanthera philoxeroides (Mart.) Griseb.               NaN
# 3                    Ameiurus melas (Rafinesque, 1820)  NHMSYS0000544615
# 4                                 Asclepias syriaca L.  INBSYS0000005932
# 5           Symphyotrichum salignum (Willd.) G.L.Nesom               NaN
# 6                                                  NaN               NaN
# 7                         Bison bison (Linnaeus, 1758)               NaN
# 8                          Cabomba caroliniana A. Gray  NHMSYS0000456744
# 9               Callosciurus erythraeus (Pallas, 1779)  INBSYS0000012711
# 10                       Caprella mutica Schurin, 1935  INBSYS0000046323
# 11                        Castor canadensis Kuhl, 1820  INBSYS0000012718
# 12                        Castor canadensis Kuhl, 1820  INBSYS0000032589
# 13    Celastrus orbiculatus C.P. Thunberg ex A. Murray  NHMSYS0100000968
# 14                     Corvus splendens Vieillot, 1817               NaN
# 15            Cotoneaster ambiguus Rehd. & E.H. Wilson  NHMSYS0000457622
# 16             Cotoneaster ascendens Flinck & B. Hylmö  NHMSYS0000457556
# 17   Cotoneaster bullatus var. floribundus (Stapf) ...  NBNSYS0100002625
# 18           Cotoneaster bullatus Bois in Bilm. & Bois  NBNSYS0000004710
# 19   Cotoneaster conspicuus H. F. Comber ex C. Marq...  NHMSYS0000457572
# 20                       Cotoneaster coriaceus Franch.  NHMSYS0000457601
# 21                   Cotoneaster dammeri C.K. Schneid.  NHMSYS0000457575
# 22                   Cotoneaster dammeri C.K. Schneid.  INBSYS0000011373
# 23                    Cotoneaster dielsianus E. Pritz.  NBNSYS0000014211
# 24                    Cotoneaster dielsianus E. Pritz.  NHMSYS0000457576
# 25                    Cotoneaster dielsianus E. Pritz.  INBSYS0000005539
# 26                    Cotoneaster dielsianus E. Pritz.  NBNSYS0100002637
# 27         Cotoneaster divaricatus Rehd. & E.H. Wilson  NBNSYS0000014035
# 28                       Cotoneaster fangianus T.T. Yu  NBNSYS0100002626
# 29                       Cotoneaster franchetii Boiss.  NBNSYS0000014170
# ..                                                 ...               ...
# 194                 Rapana venosa (Valenciennes, 1846)  INBSYS0000032669
# 195                        Sagittaria latifolia Willd.  NBNSYS0000002106
# 196                             Sarracenia purpurea L.  NBNSYS0000003523
# 197           Sargassum muticum (Yendo) Fensholt, 1955  NBNSYS0000188809
# 198        Sciurus (Sciurus) carolinensis Gmelin, 1788  NBNSYS0000005109
# 199        Sciurus (Sciurus) carolinensis Gmelin, 1788  NHMSYS0000332764
# 200             Sciurus (Sciurus) niger Linnaeus, 1758               NaN
# 201                                Sicyos angulatus L.  NBNSYS0000034270
# 202                              Solanum eleagnifolium  NBNSYS0200003195
# 203                   Euthamia graminifolia (L.) Nutt.  INBSYS0000005315
# 204                   Euthamia graminifolia (L.) Nutt.  NBNSYS0000004420
# 205                    Spartina pectinata Bosc ex Link  NBNSYS0000014303
# 206                    Spartina pectinata Bosc ex Link  NHMSYS0000463858
# 207                    Spartina pectinata Bosc ex Link  INBSYS0000009805
# 208            Spartina townsendii H.Groves & J.Groves  INBSYS0000003939
# 209            Spartina townsendii H.Groves & J.Groves  NBNSYS0000002679
# 210            Spartina townsendii H.Groves & J.Groves  NHMSYS0000463860
# 211                             Spiraea salicifolia L.  NHMSYS0000463917
# 212                             Spiraea salicifolia L.  NBNSYS0000003313
# 213                               Spiraea tomentosa L.  NHMSYS0000463792
# 214                               Spiraea tomentosa L.  INBSYS0000003949
# 215                               Spiraea tomentosa L.  NBNSYS0000014018
# 216                               Spiraea tomentosa L.  NBNSYS0000014176
# 217              Spiraea ×pseudosalicifolia Silverside  INBSYS0000003921
# 218        Tamias (Eutamias) sibiricus (Laxmann, 1769)  INBSYS0000012543
# 219            Threskiornis aethiopicus (Latham, 1790)  NHMSYS0000534047
# 220                   Trachemys scripta Schoepff, 1792  NHMSYS0000080227
# 221                   Trachemys scripta Schoepff, 1792  INBSYS0000012414
# 222                            Vallisneria spiralis L.  NBNSYS0000002118
# 223                    Vespa velutina Lepeletier, 1836               NaN
#
#     NBN_status NBN_confidence  \
# 0     ACCEPTED            100
# 1      SYNONYM            100
# 2          NaN            NaN
# 3     ACCEPTED            100
# 4     ACCEPTED             99
# 5          NaN            NaN
# 6          NaN            NaN
# 7          NaN            NaN
# 8     ACCEPTED            100
# 9     ACCEPTED            100
# 10    ACCEPTED            100
# 11    ACCEPTED            100
# 12    ACCEPTED            100
# 13    ACCEPTED             99
# 14         NaN            NaN
# 15     SYNONYM            100
# 16    ACCEPTED            100
# 17     SYNONYM            100
# 18    ACCEPTED            100
# 19    ACCEPTED             99
# 20     SYNONYM            100
# 21    ACCEPTED            100
# 22    ACCEPTED            100
# 23    ACCEPTED             99
# 24    ACCEPTED             99
# 25    ACCEPTED             99
# 26     SYNONYM            100
# 27    ACCEPTED            100
# 28    ACCEPTED            100
# 29     SYNONYM            100
# ..         ...            ...
# 194   ACCEPTED            100
# 195   ACCEPTED            100
# 196   ACCEPTED             99
# 197   ACCEPTED             95
# 198   ACCEPTED            100
# 199   ACCEPTED            100
# 200        NaN            NaN
# 201   ACCEPTED             99
# 202   ACCEPTED            100
# 203    SYNONYM             98
# 204    SYNONYM             98
# 205   ACCEPTED            100
# 206   ACCEPTED            100
# 207   ACCEPTED            100
# 208   ACCEPTED            100
# 209   ACCEPTED            100
# 210   ACCEPTED            100
# 211   ACCEPTED             99
# 212   ACCEPTED             99
# 213    SYNONYM            100
# 214    SYNONYM            100
# 215    SYNONYM            100
# 216   ACCEPTED             99
# 217   ACCEPTED             88
# 218   ACCEPTED            100
# 219   ACCEPTED            100
# 220   ACCEPTED             99
# 221   ACCEPTED             99
# 222   ACCEPTED            100
# 223        NaN            NaN
#
#                                     NBN_scientificName  \
# 0                                         Acer negundo
# 1                                Alopochen aegyptiacus
# 2                                                  NaN
# 3                                       Ameiurus melas
# 4                                    Asclepias syriaca
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                  Cabomba caroliniana
# 9                              Callosciurus erythraeus
# 10                                     Caprella mutica
# 11                                   Castor canadensis
# 12                                   Castor canadensis
# 13                               Celastrus orbiculatus
# 14                                                 NaN
# 15                          Cotoneaster pseudoambiguus
# 16                               Cotoneaster ascendens
# 17                               Cotoneaster boisianus
# 18                                Cotoneaster bullatus
# 19                              Cotoneaster conspicuus
# 20                                 Cotoneaster lacteus
# 21                                 Cotoneaster dammeri
# 22                                 Cotoneaster dammeri
# 23                              Cotoneaster dielsianus
# 24                              Cotoneaster dielsianus
# 25                              Cotoneaster dielsianus
# 26                           Cotoneaster vilmorinianus
# 27                             Cotoneaster divaricatus
# 28                               Cotoneaster fangianus
# 29                              Cotoneaster insculptus
# ..                                                 ...
# 194                                      Rapana venosa
# 195                               Sagittaria latifolia
# 196                                Sarracenia purpurea
# 197                                  Sargassum muticum
# 198                               Sciurus carolinensis
# 199                               Sciurus carolinensis
# 200                                                NaN
# 201                                   Sicyos angulatus
# 202                              Solanum eleagnifolium
# 203  Erigeron annuus (L.) Desf. subsp. septentrionalis
# 204                              Solidago graminifolia
# 205                                 Spartina pectinata
# 206                                 Spartina pectinata
# 207                                 Spartina pectinata
# 208                                Spartina townsendii
# 209                              Spartina x townsendii
# 210                              Spartina x townsendii
# 211                           Spiraea salicifolia agg.
# 212                                Spiraea salicifolia
# 213                                 Sorbaria tomentosa
# 214                                 Sorbaria tomentosa
# 215                                 Sorbaria tomentosa
# 216                                  Spiraea tomentosa
# 217                       Spiraea x pseudosalicifolius
# 218                                   Tamias sibiricus
# 219                           Threskiornis aethiopicus
# 220                                  Trachemys scripta
# 221                                  Trachemys scripta
# 222                               Vallisneria spiralis
# 223                                                NaN
#
#          NBN_taxon_group_info
# 0                  bloemplant
# 1                       vogel
# 2                         NaN
# 3    beenvis (Actinopterygii)
# 4                  bloemplant
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                  bloemplant
# 9                landzoogdier
# 10                 schaaldier
# 11               landzoogdier
# 12               landzoogdier
# 13                 bloemplant
# 14                        NaN
# 15                 bloemplant
# 16                 bloemplant
# 17                 bloemplant
# 18                 bloemplant
# 19                 bloemplant
# 20                 bloemplant
# 21                 bloemplant
# 22                 bloemplant
# 23                 bloemplant
# 24                 bloemplant
# 25                 bloemplant
# 26                 bloemplant
# 27                 bloemplant
# 28                 bloemplant
# 29                 bloemplant
# ..                        ...
# 194        mollusk (Mollusca)
# 195                bloemplant
# 196                bloemplant
# 197                      wier
# 198              landzoogdier
# 199              landzoogdier
# 200                       NaN
# 201                bloemplant
# 202                bloemplant
# 203                bloemplant
# 204                bloemplant
# 205                bloemplant
# 206                bloemplant
# 207                bloemplant
# 208                bloemplant
# 209                bloemplant
# 210                bloemplant
# 211                bloemplant
# 212                bloemplant
# 213                bloemplant
# 214                bloemplant
# 215                bloemplant
# 216                bloemplant
# 217                bloemplant
# 218              landzoogdier
# 219                     vogel
# 220                   reptiel
# 221                   reptiel
# 222                bloemplant
# 223                       NaN
#
# [224 rows x 9 columns]

# %% [markdown]
# ###  Manual additions and adaptations accoring to issue #28

# %% [markdown]
# https://github.com/LifeWatchINBO/invasive-t0-occurrences/issues/28

# %%
species_info_recorder_matches.head()
# Out:
#                           name   kingdom gbifapi_acceptedKey  \
# 0                 Acer negundo   Plantae             3189866
# 1         Alopochen aegyptiaca  Animalia             2498252
# 2  Alternanthera philoxeroides   Plantae             3084923
# 3               Ameiurus melas  Animalia             2340977
# 4            Asclepias syriaca   Plantae             3170247
#
#                 gbifapi_acceptedScientificName         NBN_index NBN_status  \
# 0                              Acer negundo L.  NBNSYS0000014604   ACCEPTED
# 1        Alopochen aegyptiaca (Linnaeus, 1766)  NHMSYS0001689380    SYNONYM
# 2  Alternanthera philoxeroides (Mart.) Griseb.               NaN        NaN
# 3            Ameiurus melas (Rafinesque, 1820)  NHMSYS0000544615   ACCEPTED
# 4                         Asclepias syriaca L.  INBSYS0000005932   ACCEPTED
#
#   NBN_confidence     NBN_scientificName      NBN_taxon_group_info
# 0            100           Acer negundo                bloemplant
# 1            100  Alopochen aegyptiacus                     vogel
# 2            NaN                    NaN                       NaN
# 3            100         Ameiurus melas  beenvis (Actinopterygii)
# 4             99      Asclepias syriaca                bloemplant

# %%
recorder_matched[recorder_matched["canonicalName"] == "Oenothera angustissima"]
# Out:
#               NBN_index           canonicalName          class classKey  \
# 54806  INBSYS0000009678  Oenothera angustissima  Magnoliopsida      220
#
#       confidence      family familyKey      genus genusKey  kingdom  \
# 54806        100  Onagraceae      2430  Oenothera  3188799  Plantae
#
#                    ...              phylumKey     rank  \
# 54806              ...                7707728  SPECIES
#
#                      scientificName                 species speciesKey  \
# 54806  Oenothera angustissima Gates  Oenothera angustissima    3188889
#
#          status synonym usageKey acceptedKey        acceptedScientificName
# 54806  ACCEPTED   False  3188889     3188889  Oenothera angustissima Gates
#
# [1 rows x 26 columns]

# %% [markdown]
# Retrieved by Queries from Recorder:
#
# * NBN code for Aster x salignus: NBNSYS0000004434

# %% [markdown]
# #### Manually add codes

# %%
idx = species_info_recorder_matches[species_info_recorder_matches["name"] == "Symphyotrichum salignum"].index
species_info_recorder_matches.loc[idx, "NBN_index"] = "NBNSYS0000004434"

# %%
species_info_recorder_matches.iloc[idx]
# Out:
#                       name  kingdom gbifapi_acceptedKey  \
# 5  Symphyotrichum salignum  Plantae             3151811
#
#                gbifapi_acceptedScientificName         NBN_index NBN_status  \
# 5  Symphyotrichum salignum (Willd.) G.L.Nesom  NBNSYS0000004434        NaN
#
#   NBN_confidence NBN_scientificName NBN_taxon_group_info
# 5            NaN                NaN                  NaN

# %% [markdown]
# Oenothera angustissima -> solved

# %% [markdown]
# Oenothera x fallax -> solved

# %% [markdown]
# #### Remove NBN code, as it is already mapped elsewhere

# %% [markdown]
# Oenothera biennis -> solved

# %% [markdown]
# Oenothera oakesiana -> solved

# %% [markdown]
# Oenothera pycnocarpa -> solved

# %% [markdown]
# Parthenocissus inserta -> solved

# %% [markdown]
# Parthenocissus quinquefolia -> solved

# %%
#species_info_recorder_matches.loc[list2remove, "NBN_index"] = np.nan

# %% [markdown]
# Cotoneaster integrifolius  -> HIGHERRAN K to kingdom, no NBN-match, so considered ok

# %% [markdown]
# Oenothera depressa -> solved

# %% [markdown]
# #### Recorder original dbase names of IDS taken into account of species list:

# %%
temp = species_info_recorder_matches["NBN_index"].dropna().values.tolist()
temp = [el for el in temp if len(el)>0]

# %%
recorder_names.set_index("RECOMMENDED_TAXON_VERSION_KEY").loc[temp].to_csv("recorder_identifiers_in_species_list.csv")

# %%
species_info_recorder_matches[species_info_recorder_matches["NBN_index"] == "NBNSYS0000013948"]
# Out:
#                      name  kingdom gbifapi_acceptedKey  \
# 152  Oenothera perangusta  Plantae             7322738
# 159  Oenothera rubricalyx  Plantae             7322738
#
#     gbifapi_acceptedScientificName         NBN_index NBN_status  \
# 152     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
# 159     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
#
#     NBN_confidence    NBN_scientificName NBN_taxon_group_info
# 152            100  Oenothera perangusta           bloemplant
# 159            100  Oenothera perangusta           bloemplant

# %% [markdown]
# #### Query creation: prepare ids

# %% [markdown]
# Prepare the set of NBN-identifiers to make the query in the recorder dbase:

# %%
species_info_recorder_matches = species_info_recorder_matches.fillna('')

# %%
key_list_dbase = "','".join(species_info_recorder_matches["NBN_index"].values.tolist())

# %%
import re

# %%
key_list_dbase = re.sub(",''","", key_list_dbase)

# %%
re.sub("[0-9],[A-Z]", "','", key_list_dbase)

# %%
key_list_dbase

# %% [markdown]
# ### Reformat the table back to the original format by combining multiple references

# %%
grouped_species_list = species_info_recorder_matches[["name", "kingdom", "gbifapi_acceptedKey", "gbifapi_acceptedScientificName"]].drop_duplicates()

# %%
grouped_species_list[grouped_species_list["gbifapi_acceptedKey"] == "7322738"]
# Out:
#                      name  kingdom gbifapi_acceptedKey  \
# 152  Oenothera perangusta  Plantae             7322738
# 159  Oenothera rubricalyx  Plantae             7322738
#
#     gbifapi_acceptedScientificName
# 152     Oenothera perangusta Gates
# 159     Oenothera perangusta Gates

# %%
grouped_species_list = grouped_species_list.set_index("name")

# %%
species_info_recorder_matches[species_info_recorder_matches["NBN_index"] == "NBNSYS0000013948"]
# Out:
#                      name  kingdom gbifapi_acceptedKey  \
# 152  Oenothera perangusta  Plantae             7322738
# 159  Oenothera rubricalyx  Plantae             7322738
#
#     gbifapi_acceptedScientificName         NBN_index NBN_status  \
# 152     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
# 159     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
#
#     NBN_confidence    NBN_scientificName NBN_taxon_group_info
# 152            100  Oenothera perangusta           bloemplant
# 159            100  Oenothera perangusta           bloemplant

# %%
species_info_recorder_matches["NBN_scientificName"] = species_info_recorder_matches["NBN_scientificName"].astype(str)
temp = species_info_recorder_matches.groupby('name')["NBN_scientificName"].apply(','.join)

# %%
for NBN in ["NBN_index", "NBN_status", "NBN_confidence", "NBN_scientificName", "NBN_taxon_group_info"]:
    species_info_recorder_matches[NBN] = species_info_recorder_matches[NBN].astype(str)
    grouped_species_list[NBN] = species_info_recorder_matches.groupby('name')[NBN].apply(','.join)

# %%
grouped_species_list = grouped_species_list.reset_index()

# %%
grouped_species_list = grouped_species_list.rename(columns={"NBN_index":"nbnTaxonID"})

# %%
#grouped_species_list.to_csv("species_list_with_recorder_version.csv")

# %%
grouped_species_list["nbnTaxonID"] = grouped_species_list["nbnTaxonID"].replace('(,,+)', ',', regex=True)
grouped_species_list["nbnTaxonID"] = grouped_species_list["nbnTaxonID"].replace('^,', '', regex=True)
grouped_species_list["nbnTaxonID"] = grouped_species_list["nbnTaxonID"].replace(',$', '', regex=True)

# %%
pandas_df_to_markdown_table(grouped_species_list)

# %%
grouped_species_list[grouped_species_list["nbnTaxonID"] == "NBNSYS0000013948"]
# Out:
#                      name  kingdom gbifapi_acceptedKey  \
# 102  Oenothera perangusta  Plantae             7322738
# 107  Oenothera rubricalyx  Plantae             7322738
#
#     gbifapi_acceptedScientificName        nbnTaxonID NBN_status  \
# 102     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
# 107     Oenothera perangusta Gates  NBNSYS0000013948   ACCEPTED
#
#     NBN_confidence    NBN_scientificName NBN_taxon_group_info
# 102            100  Oenothera perangusta           bloemplant
# 107            100  Oenothera perangusta           bloemplant

# %%
# Out:
#     index                              name    kingdom      euConcernStatus  \
# 0       0                      Acer negundo    Plantae  under consideration
# 1       1              Alopochen aegyptiaca   Animalia  under consideration
# 2       2       Alternanthera philoxeroides    Plantae  under consideration
# 3       3                    Ameiurus melas   Animalia  under consideration
# 4       4                 Asclepias syriaca    Plantae  under consideration
# 5       5           Symphyotrichum salignum    Plantae                  NaN
# 6       6             Baccharis halimifolia    Plantae               listed
# 7       7                       Bison bison   Animalia  under consideration
# 8       8               Cabomba caroliniana    Plantae               listed
# 9       9           Callosciurus erythraeus   Animalia               listed
# 10     10                   Caprella mutica   Animalia           not listed
# 11     11                 Castor canadensis   Animalia                  NaN
# 12     12             Celastrus orbiculatus    Plantae                  NaN
# 13     13                  Corvus splendens   Animalia               listed
# 14     14              Cotoneaster ambiguus    Plantae                  NaN
# 15     15             Cotoneaster ascendens    Plantae                  NaN
# 16     16             Cotoneaster boisianus    Plantae                  NaN
# 17     17              Cotoneaster bullatus    Plantae                  NaN
# 18     18            Cotoneaster conspicuus    Plantae                  NaN
# 19     19             Cotoneaster coriaceus    Plantae                  NaN
# 20     20               Cotoneaster dammeri    Plantae                  NaN
# 21     21            Cotoneaster dielsianus    Plantae                  NaN
# 22     22           Cotoneaster divaricatus    Plantae                  NaN
# 23     23             Cotoneaster fangianus    Plantae                  NaN
# 24     24            Cotoneaster franchetii    Plantae                  NaN
# 25     25         Cotoneaster ganghobaensis    Plantae                  NaN
# 26     26          Cotoneaster hjelmqvistii    Plantae                  NaN
# 27     27          Cotoneaster horizontalis    Plantae                  NaN
# 28     28               Cotoneaster hylmoei    Plantae                  NaN
# 29     29         Cotoneaster integrifolius    Plantae                  NaN
# ..    ...                               ...        ...                  ...
# 122   129       Parthenocissus quinquefolia    Plantae                  NaN
# 123   131       Parthenocissus tricuspidata    Plantae                  NaN
# 124   132               Pennisetum setaceum    Plantae  under consideration
# 125   133                 Perccottus glenii   Animalia               listed
# 126   134             Persicaria perfoliata    Plantae               listed
# 127   135                Pontederia cordata    Plantae                  NaN
# 128   136               Procambarus clarkii   Animalia               listed
# 129   137  Procambarus fallax f. virginalis   Animalia               listed
# 130   138                     Procyon lotor   Animalia               listed
# 131   139               Pseudorasbora parva   Animalia               listed
# 132   140                  Pueraria montana    Plantae               listed
# 133   141                     Rapana venosa   Animalia           not listed
# 134   142              Sagittaria latifolia    Plantae                  NaN
# 135   143               Sarracenia purpurea    Plantae                  NaN
# 136   144                 Sargassum muticum  Eukaryota           not listed
# 137   145              Sciurus carolinensis   Animalia               listed
# 138   146                     Sciurus niger   Animalia               listed
# 139   147                  Sicyos angulatus    Plantae           not listed
# 140   148             Solanum eleagnifolium    Plantae           not listed
# 141   149             Euthamia graminifolia    Plantae    under preparation
# 142   150                Spartina pectinata    Plantae                  NaN
# 143   151               Spartina townsendii    Plantae                  NaN
# 144   152               Spiraea salicifolia    Plantae                  NaN
# 145   153                 Spiraea tomentosa    Plantae    under preparation
# 146   154         Spiraea pseudosalicifolia    Plantae                  NaN
# 147   155                  Tamias sibiricus   Animalia               listed
# 148   156          Threskiornis aethiopicus   Animalia               listed
# 149   157                 Trachemys scripta   Animalia               listed
# 150   158              Vallisneria spiralis    Plantae                  NaN
# 151   159                    Vespa velutina   Animalia               listed
#
#     gbifapi_usageKey                             gbifapi_scientificName  \
# 0            3189866                                    Acer negundo L.
# 1            2498252              Alopochen aegyptiaca (Linnaeus, 1766)
# 2            3084923        Alternanthera philoxeroides (Mart.) Griseb.
# 3            2340977                  Ameiurus melas (Rafinesque, 1820)
# 4            3170247                               Asclepias syriaca L.
# 5            3151811         Symphyotrichum salignum (Willd.) G.L.Nesom
# 6                NaN                                                NaN
# 7            2441176                       Bison bison (Linnaeus, 1758)
# 8            2882443                        Cabomba caroliniana A. Gray
# 9            2437394             Callosciurus erythraeus (Pallas, 1779)
# 10           5178057                      Caprella mutica Schurin, 1935
# 11           2439838                       Castor canadensis Kuhl, 1820
# 12           8104460   Celastrus orbiculatus C.P. Thunberg ex A. Murray
# 13           2482499                    Corvus splendens Vieillot, 1817
# 14           3025858           Cotoneaster ambiguus Rehd. & E.H. Wilson
# 15           3026024            Cotoneaster ascendens Flinck & B. Hylmö
# 16           3026167                     Cotoneaster boisianus G. Klotz
# 17           3026294          Cotoneaster bullatus Bois in Bilm. & Bois
# 18           3025875  Cotoneaster conspicuus H. F. Comber ex C. Marq...
# 19           3026035                      Cotoneaster coriaceus Franch.
# 20           3026049                  Cotoneaster dammeri C.K. Schneid.
# 21           3025896                   Cotoneaster dielsianus E. Pritz.
# 22           3026334        Cotoneaster divaricatus Rehd. & E.H. Wilson
# 23           3025932                      Cotoneaster fangianus T.T. Yu
# 24           3026162                      Cotoneaster franchetii Boiss.
# 25           3025989      Cotoneaster ganghobaensis J. Fryer & B. Hylmö
# 26           3026092    Cotoneaster hjelmqvistii K.E. Flinck & B. Hylmö
# 27           3025617                     Cotoneaster horizontalis Decne
# 28           3025758         Cotoneaster hylmoei K.E. Flinck & J. Fryer
# 29               NaN                                                NaN
# ..               ...                                                ...
# 122          3039194          Parthenocissus quinquefolia (L.) Planchon
# 123          3039209  Parthenocissus tricuspidata (Siebold & Zucc.) ...
# 124          2706134               Pennisetum setaceum (Forssk.) Chiov.
# 125          2390064                   Perccottus glenii Dybowski, 1877
# 126          4033648                Persicaria perfoliata (L.) H. Gross
# 127          2766030                              Pontederia cordata L.
# 128          2227300  Procambarus (Scapulicambarus) clarkii (Girard,...
# 129              NaN                                                NaN
# 130          5218786                     Procyon lotor (Linnaeus, 1758)
# 131          2362868    Pseudorasbora parva (Temminck & Schlegel, 1846)
# 132          2977636                      Pueraria montana (Lour.)Merr.
# 133          4363583                 Rapana venosa (Valenciennes, 1846)
# 134          5328909                        Sagittaria latifolia Willd.
# 135          5421389                             Sarracenia purpurea L.
# 136          3197314           Sargassum muticum (Yendo) Fensholt, 1955
# 137          5219681        Sciurus (Sciurus) carolinensis Gmelin, 1788
# 138          5219683             Sciurus (Sciurus) niger Linnaeus, 1758
# 139          2874655                                Sicyos angulatus L.
# 140          7299960                              Solanum eleagnifolium
# 141          3092782                   Euthamia graminifolia (L.) Nutt.
# 142          5290030                    Spartina pectinata Bosc ex Link
# 143          5290034            Spartina townsendii H.Groves & J.Groves
# 144          3026454                             Spiraea salicifolia L.
# 145          3026819                               Spiraea tomentosa L.
# 146          3026444              Spiraea ×pseudosalicifolia Silverside
# 147          2437450        Tamias (Eutamias) sibiricus (Laxmann, 1769)
# 148          2480764            Threskiornis aethiopicus (Latham, 1790)
# 149          2443002                   Trachemys scripta Schoepff, 1792
# 150          2865526                            Vallisneria spiralis L.
# 151          1311477                    Vespa velutina Lepeletier, 1836
#
#            gbifapi_canonicalName gbifapi_status gbifapi_rank  \
# 0                   Acer negundo       ACCEPTED      SPECIES
# 1           Alopochen aegyptiaca       ACCEPTED      SPECIES
# 2    Alternanthera philoxeroides       ACCEPTED      SPECIES
# 3                 Ameiurus melas       ACCEPTED      SPECIES
# 4              Asclepias syriaca       ACCEPTED      SPECIES
# 5        Symphyotrichum salignum       DOUBTFUL      SPECIES
# 6                            NaN            NaN          NaN
# 7                    Bison bison       ACCEPTED      SPECIES
# 8            Cabomba caroliniana       ACCEPTED      SPECIES
# 9        Callosciurus erythraeus       ACCEPTED      SPECIES
# 10               Caprella mutica       ACCEPTED      SPECIES
# 11             Castor canadensis       ACCEPTED      SPECIES
# 12         Celastrus orbiculatus       ACCEPTED      SPECIES
# 13              Corvus splendens       ACCEPTED      SPECIES
# 14          Cotoneaster ambiguus       ACCEPTED      SPECIES
# 15         Cotoneaster ascendens       ACCEPTED      SPECIES
# 16         Cotoneaster boisianus        SYNONYM      SPECIES
# 17          Cotoneaster bullatus       ACCEPTED      SPECIES
# 18        Cotoneaster conspicuus       ACCEPTED      SPECIES
# 19         Cotoneaster coriaceus       ACCEPTED      SPECIES
# 20           Cotoneaster dammeri       ACCEPTED      SPECIES
# 21        Cotoneaster dielsianus       ACCEPTED      SPECIES
# 22       Cotoneaster divaricatus       ACCEPTED      SPECIES
# 23         Cotoneaster fangianus       ACCEPTED      SPECIES
# 24        Cotoneaster franchetii       ACCEPTED      SPECIES
# 25     Cotoneaster ganghobaensis        SYNONYM      SPECIES
# 26      Cotoneaster hjelmqvistii       ACCEPTED      SPECIES
# 27      Cotoneaster horizontalis       ACCEPTED      SPECIES
# 28           Cotoneaster hylmoei        SYNONYM      SPECIES
# 29                           NaN            NaN          NaN
# ..                           ...            ...          ...
# 122  Parthenocissus quinquefolia       ACCEPTED      SPECIES
# 123  Parthenocissus tricuspidata       ACCEPTED      SPECIES
# 124          Pennisetum setaceum       ACCEPTED      SPECIES
# 125            Perccottus glenii       ACCEPTED      SPECIES
# 126        Persicaria perfoliata        SYNONYM      SPECIES
# 127           Pontederia cordata       ACCEPTED      SPECIES
# 128          Procambarus clarkii       ACCEPTED      SPECIES
# 129                          NaN            NaN          NaN
# 130                Procyon lotor       ACCEPTED      SPECIES
# 131          Pseudorasbora parva       ACCEPTED      SPECIES
# 132             Pueraria montana        SYNONYM      SPECIES
# 133                Rapana venosa       ACCEPTED      SPECIES
# 134         Sagittaria latifolia       ACCEPTED      SPECIES
# 135          Sarracenia purpurea       ACCEPTED      SPECIES
# 136            Sargassum muticum       ACCEPTED      SPECIES
# 137         Sciurus carolinensis       ACCEPTED      SPECIES
# 138                Sciurus niger       ACCEPTED      SPECIES
# 139             Sicyos angulatus       ACCEPTED      SPECIES
# 140        Solanum eleagnifolium       ACCEPTED      SPECIES
# 141        Euthamia graminifolia       DOUBTFUL      SPECIES
# 142           Spartina pectinata       ACCEPTED      SPECIES
# 143          Spartina townsendii       ACCEPTED      SPECIES
# 144          Spiraea salicifolia       ACCEPTED      SPECIES
# 145            Spiraea tomentosa       ACCEPTED      SPECIES
# 146    Spiraea pseudosalicifolia       ACCEPTED      SPECIES
# 147             Tamias sibiricus       ACCEPTED      SPECIES
# 148     Threskiornis aethiopicus       ACCEPTED      SPECIES
# 149            Trachemys scripta       ACCEPTED      SPECIES
# 150         Vallisneria spiralis       ACCEPTED      SPECIES
# 151               Vespa velutina       ACCEPTED      SPECIES
#
#     gbifapi_matchType gbifapi_confidence gbifapi_acceptedKey  \
# 0               EXACT                100             3189866
# 1               EXACT                100             2498252
# 2               EXACT                100             3084923
# 3               EXACT                100             2340977
# 4               EXACT                 99             3170247
# 5               EXACT                100             3151811
# 6                 NaN                NaN                 NaN
# 7               EXACT                100             2441176
# 8               EXACT                100             2882443
# 9               EXACT                100             2437394
# 10              EXACT                100             5178057
# 11              EXACT                100             2439838
# 12              EXACT                 99             8104460
# 13              EXACT                100             2482499
# 14              EXACT                100             3025858
# 15              EXACT                100             3026024
# 16              EXACT                100             3026295
# 17              EXACT                100             3026294
# 18              EXACT                 99             3025875
# 19              EXACT                100             3026035
# 20              EXACT                100             3026049
# 21              EXACT                 99             3025896
# 22              EXACT                100             3026334
# 23              EXACT                100             3025932
# 24              EXACT                100             3026162
# 25              EXACT                100             3026007
# 26              EXACT                100             3026092
# 27              EXACT                 99             3025617
# 28              EXACT                100             3026076
# 29                NaN                NaN                 NaN
# ..                ...                ...                 ...
# 122             EXACT                 99             3039194
# 123             EXACT                100             3039209
# 124             EXACT                100             2706134
# 125             EXACT                100             2390064
# 126             EXACT                100             4037171
# 127             EXACT                100             2766030
# 128             EXACT                100             2227300
# 129               NaN                NaN                 NaN
# 130             EXACT                100             5218786
# 131             EXACT                100             2362868
# 132             EXACT                100             5352354
# 133             EXACT                100             4363583
# 134             EXACT                100             5328909
# 135             EXACT                 99             5421389
# 136             EXACT                 95             3197314
# 137             EXACT                100             5219681
# 138             EXACT                100             5219683
# 139             EXACT                 99             2874655
# 140             EXACT                100             7299960
# 141             EXACT                 97             3092782
# 142             EXACT                100             5290030
# 143             EXACT                100             5290034
# 144             EXACT                 99             3026454
# 145             EXACT                 99             3026819
# 146             EXACT                100             3026444
# 147             EXACT                100             2437450
# 148             EXACT                100             2480764
# 149             EXACT                 99             2443002
# 150             EXACT                100             2865526
# 151             EXACT                100             1311477
#
#                         gbifapi_acceptedScientificName
# 0                                      Acer negundo L.
# 1                Alopochen aegyptiaca (Linnaeus, 1766)
# 2          Alternanthera philoxeroides (Mart.) Griseb.
# 3                    Ameiurus melas (Rafinesque, 1820)
# 4                                 Asclepias syriaca L.
# 5           Symphyotrichum salignum (Willd.) G.L.Nesom
# 6                                                  NaN
# 7                         Bison bison (Linnaeus, 1758)
# 8                          Cabomba caroliniana A. Gray
# 9               Callosciurus erythraeus (Pallas, 1779)
# 10                       Caprella mutica Schurin, 1935
# 11                        Castor canadensis Kuhl, 1820
# 12    Celastrus orbiculatus C.P. Thunberg ex A. Murray
# 13                     Corvus splendens Vieillot, 1817
# 14            Cotoneaster ambiguus Rehd. & E.H. Wilson
# 15             Cotoneaster ascendens Flinck & B. Hylmö
# 16   Cotoneaster bullatus var. floribundus (Stapf) ...
# 17           Cotoneaster bullatus Bois in Bilm. & Bois
# 18   Cotoneaster conspicuus H. F. Comber ex C. Marq...
# 19                       Cotoneaster coriaceus Franch.
# 20                   Cotoneaster dammeri C.K. Schneid.
# 21                    Cotoneaster dielsianus E. Pritz.
# 22         Cotoneaster divaricatus Rehd. & E.H. Wilson
# 23                       Cotoneaster fangianus T.T. Yu
# 24                       Cotoneaster franchetii Boiss.
# 25                      Cotoneaster lambertii G. Klotz
# 26     Cotoneaster hjelmqvistii K.E. Flinck & B. Hylmö
# 27                      Cotoneaster horizontalis Decne
# 28   Cotoneaster salicifolius var. rugosus (E. Prit...
# 29                                                 NaN
# ..                                                 ...
# 122          Parthenocissus quinquefolia (L.) Planchon
# 123  Parthenocissus tricuspidata (Siebold & Zucc.) ...
# 124               Pennisetum setaceum (Forssk.) Chiov.
# 125                   Perccottus glenii Dybowski, 1877
# 126                    Truellum perfoliatum (L.) Soják
# 127                              Pontederia cordata L.
# 128  Procambarus (Scapulicambarus) clarkii (Girard,...
# 129                                                NaN
# 130                     Procyon lotor (Linnaeus, 1758)
# 131    Pseudorasbora parva (Temminck & Schlegel, 1846)
# 132                               Anthyllis montana L.
# 133                 Rapana venosa (Valenciennes, 1846)
# 134                        Sagittaria latifolia Willd.
# 135                             Sarracenia purpurea L.
# 136           Sargassum muticum (Yendo) Fensholt, 1955
# 137        Sciurus (Sciurus) carolinensis Gmelin, 1788
# 138             Sciurus (Sciurus) niger Linnaeus, 1758
# 139                                Sicyos angulatus L.
# 140                              Solanum eleagnifolium
# 141                   Euthamia graminifolia (L.) Nutt.
# 142                    Spartina pectinata Bosc ex Link
# 143            Spartina townsendii H.Groves & J.Groves
# 144                             Spiraea salicifolia L.
# 145                               Spiraea tomentosa L.
# 146              Spiraea ×pseudosalicifolia Silverside
# 147        Tamias (Eutamias) sibiricus (Laxmann, 1769)
# 148            Threskiornis aethiopicus (Latham, 1790)
# 149                   Trachemys scripta Schoepff, 1792
# 150                            Vallisneria spiralis L.
# 151                    Vespa velutina Lepeletier, 1836
#
# [152 rows x 13 columns]

# %%
grouped_species_list.head()
# Out:
#                           name   kingdom gbifapi_acceptedKey  \
# 0                 Acer negundo   Plantae             3189866
# 1         Alopochen aegyptiaca  Animalia             2498252
# 2  Alternanthera philoxeroides   Plantae             3084923
# 3               Ameiurus melas  Animalia             2340977
# 4            Asclepias syriaca   Plantae             3170247
#
#                 gbifapi_acceptedScientificName        nbnTaxonID NBN_status  \
# 0                              Acer negundo L.  NBNSYS0000014604   ACCEPTED
# 1        Alopochen aegyptiaca (Linnaeus, 1766)  NHMSYS0001689380    SYNONYM
# 2  Alternanthera philoxeroides (Mart.) Griseb.               nan        nan
# 3            Ameiurus melas (Rafinesque, 1820)  NHMSYS0000544615   ACCEPTED
# 4                         Asclepias syriaca L.  INBSYS0000005932   ACCEPTED
#
#   NBN_confidence     NBN_scientificName      NBN_taxon_group_info
# 0            100           Acer negundo                bloemplant
# 1            100  Alopochen aegyptiacus                     vogel
# 2            nan                    nan                       nan
# 3            100         Ameiurus melas  beenvis (Actinopterygii)
# 4             99      Asclepias syriaca                bloemplant

# %%
invasive_species_update = pd.merge(invasive_species.drop("nbnTaxonID", axis=1), 
                                   grouped_species_list[["name", 
                                                         "nbnTaxonID",
                                                         "NBN_scientificName"]], 
                                   on='name')

# %%
invasive_species_update = invasive_species_update.drop("index", axis=1)

# %%
invasive_species_update = invasive_species_update.replace("nan", np.nan)

# %%
invasive_species_update.to_csv("species_list.tsv", index=False, sep='\t', na_rep="")

# %%
invasive_species_update[invasive_species_update["name"] == "Oenothera rubricalyx"]
# Out:
#                      name  kingdom euConcernStatus gbifapi_usageKey  \
# 107  Oenothera rubricalyx  Plantae             NaN          3665866
#
#              gbifapi_scientificName gbifapi_canonicalName gbifapi_status  \
# 107  Oenothera rubricalyx R.R.Gates  Oenothera rubricalyx        SYNONYM
#
#     gbifapi_rank gbifapi_matchType gbifapi_confidence gbifapi_acceptedKey  \
# 107      SPECIES             EXACT                100             7322738
#
#     gbifapi_acceptedScientificName        nbnTaxonID    NBN_scientificName
# 107     Oenothera perangusta Gates  NBNSYS0000013948  Oenothera perangusta

# %% [markdown]
# ### The issue of Hyacinthoides hispanica

# %%
recorder_names[recorder_names["scientificName"].str.contains("Hyacinthoides hispanica")]

# %%
recorder_matched[recorder_matched["NBN_index"] == "INBSYS0000004090"]

# %%
extract_gbif_species_names_info("Hyacinthoides hispanica", "Plantae")

# %%
occ_hyacinth = pd.read_csv("occurrences_Hyacinthoides_hispanica.csv", delimiter='\t')

# %%
occ_hyacinth.groupby("ITEM_NAME").count().index
