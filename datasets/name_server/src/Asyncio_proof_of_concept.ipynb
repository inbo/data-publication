# %% [markdown]
# # Asyncio testcase

# %%
import asyncio

import aiohttp
import pandas as pd

# %%
import sys
sys.path.append("../gbif_species_name_extraction/")
from gbif_species_name_extraction import extract_species_information, extract_gbif_species_names_info

# %% [markdown]
# http://aiohttp.readthedocs.org/en/stable/

# %%
name = 'Crypsis schoenoides'
params = {'verbose': False, 'strict': True, 'name' : name}

# %%
recorder_names = pd.read_csv("recorder_sql_unique_names_output.csv", delimiter='\t', dtype=object)

# %%
testcase = recorder_names["scientificName"].values[:30]

# %%
recorder_names["scientificName"].values[:30]
# Out:
# array(['Caylusea', 'Listrognathus mactator', 'Paratanytarsus dissimilis',
#        'Gymnodinium colymbeticum', 'Formicinae', 'Tryblionella scalaris',
#        'Dinocheirus', 'Euglena granulata', 'Brachionis leydigi',
#        'Anurophorus satchelli', 'Noxius curtirostris',
#        'Anthelia juratzkana', 'Ammonia flevensis', 'Plectus tenuis',
#        'Mycosphaerellaceae', 'Chrysopilus cristatus',
#        'Anisoplia ?agricola', 'Crypsis schoenoides', 'Tritaphros retzii',
#        'Crepidotus tubidulus', 'Olpidium gregarium',
#        'Tragopogon pratensis L. subsp. orientalis',
#        'Diaporthe phaseolorum', 'Lumbriculus variegatus',
#        'Alytes cisternasii', 'Periplomatidae', 'Odontophora',
#        'Lestodiplosis affinis', 'Panicum clandestinum', 'Furcula'], dtype=object)

# %%
testcase
# Out:
# array(['Caylusea', 'Listrognathus mactator', 'Paratanytarsus dissimilis',
#        'Gymnodinium colymbeticum', 'Formicinae', 'Tryblionella scalaris',
#        'Dinocheirus', 'Euglena granulata', 'Brachionis leydigi',
#        'Anurophorus satchelli', 'Noxius curtirostris',
#        'Anthelia juratzkana', 'Ammonia flevensis', 'Plectus tenuis',
#        'Mycosphaerellaceae', 'Chrysopilus cristatus',
#        'Anisoplia ?agricola', 'Crypsis schoenoides', 'Tritaphros retzii',
#        'Crepidotus tubidulus', 'Olpidium gregarium',
#        'Tragopogon pratensis L. subsp. orientalis',
#        'Diaporthe phaseolorum', 'Lumbriculus variegatus',
#        'Alytes cisternasii', 'Periplomatidae', 'Odontophora',
#        'Lestodiplosis affinis', 'Panicum clandestinum', 'Furcula'], dtype=object)

# %%
class Collector():
    
    def __init__(self):
        self.data = {}

    async def fetch(self, session, name):
        parameters = {'verbose': False, 'strict': True, 'name' : name}
        async with client.get('http://api.gbif.org/v1/species/match', params=parameters) as resp:
            assert resp.status == 200
            self.data[name] = await resp.json()

# %%
test = Collector()
with aiohttp.ClientSession() as client:
    asyncio.get_event_loop().run_until_complete(asyncio.wait([test.fetch(client, name) for name in testcase]))

# %%
test.data
# Out:
# {'Alytes cisternasii': {'canonicalName': 'Alytes cisternasii',
#   'class': 'Amphibia',
#   'classKey': 131,
#   'confidence': 100,
#   'family': 'Alytidae',
#   'familyKey': 6726,
#   'genus': 'Alytes',
#   'genusKey': 2426608,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Anura',
#   'orderKey': 952,
#   'phylum': 'Chordata',
#   'phylumKey': 44,
#   'rank': 'SPECIES',
#   'scientificName': 'Alytes cisternasii Boscรก, 1879',
#   'species': 'Alytes cisternasii',
#   'speciesKey': 2426610,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2426610},
#  'Ammonia flevensis': {'canonicalName': 'Ammonia flevensis',
#   'class': 'Granuloreticulosea',
#   'classKey': 115,
#   'confidence': 100,
#   'family': 'Rotaliidae',
#   'familyKey': 6610,
#   'genus': 'Ammonia',
#   'genusKey': 3211070,
#   'kingdom': 'Protozoa',
#   'kingdomKey': 7,
#   'matchType': 'EXACT',
#   'order': 'Foraminiferida',
#   'orderKey': 389,
#   'rank': 'SPECIES',
#   'scientificName': 'Ammonia flevensis (Hofker)',
#   'species': 'Ammonia flevensis',
#   'speciesKey': 5731312,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5731312},
#  'Anisoplia ?agricola': {'canonicalName': 'Anisoplia',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 96,
#   'family': 'Rutelidae',
#   'familyKey': 4425773,
#   'genus': 'Anisoplia',
#   'genusKey': 4407511,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Anisoplia Schoenherr, 1817',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4407511},
#  'Anthelia juratzkana': {'canonicalName': 'Anthelia juratzkana',
#   'class': 'Jungermanniopsida',
#   'classKey': 126,
#   'confidence': 100,
#   'family': 'Antheliaceae',
#   'familyKey': 6142,
#   'genus': 'Anthelia',
#   'genusKey': 2689309,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Jungermanniales',
#   'orderKey': 381,
#   'phylum': 'Marchantiophyta',
#   'phylumKey': 9,
#   'rank': 'SPECIES',
#   'scientificName': 'Anthelia juratzkana (Limpr.) Trev.',
#   'species': 'Anthelia juratzkana',
#   'speciesKey': 5710214,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5710214},
#  'Anurophorus satchelli': {'canonicalName': 'Anurophorus satchelli',
#   'class': 'Entognatha',
#   'classKey': 290,
#   'confidence': 100,
#   'family': 'Isotomidae',
#   'familyKey': 7214,
#   'genus': 'Anurophorus',
#   'genusKey': 5166805,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Collembola',
#   'orderKey': 546,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Anurophorus satchelli Goto, 1956',
#   'species': 'Anurophorus satchelli',
#   'speciesKey': 5166810,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5166810},
#  'Brachionis leydigi': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'No match because of too little confidence',
#   'synonym': False},
#  'Caylusea': {'canonicalName': 'Caylusea',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 96,
#   'family': 'Resedaceae',
#   'familyKey': 3110,
#   'genus': 'Caylusea',
#   'genusKey': 7275943,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Brassicales',
#   'orderKey': 7225535,
#   'phylum': 'Magnoliophyta',
#   'phylumKey': 49,
#   'rank': 'GENUS',
#   'scientificName': 'Caylusea A.St.-Hil.',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 7275943},
#  'Chrysopilus cristatus': {'canonicalName': 'Chrysopilus cristatus',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Rhagionidae',
#   'familyKey': 5587,
#   'genus': 'Chrysopilus',
#   'genusKey': 5078728,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Chrysopilus cristatus (Fabricius, 1775)',
#   'species': 'Chrysopilus cristatus',
#   'speciesKey': 5766100,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5766100},
#  'Crepidotus tubidulus': {'canonicalName': 'Crepidotus tubidulus',
#   'class': 'Agaricomycetes',
#   'classKey': 186,
#   'confidence': 100,
#   'family': 'Inocybaceae',
#   'familyKey': 4177,
#   'genus': 'Crepidotus',
#   'genusKey': 2526680,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Agaricales',
#   'orderKey': 1499,
#   'phylum': 'Basidiomycota',
#   'phylumKey': 34,
#   'rank': 'SPECIES',
#   'scientificName': 'Crepidotus tubidulus anon.',
#   'species': 'Crepidotus tubidulus',
#   'speciesKey': 5453111,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5453111},
#  'Crypsis schoenoides': {'canonicalName': 'Crypsis schoenoides',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 100,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Crypsis',
#   'genusKey': 2706115,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Magnoliophyta',
#   'phylumKey': 49,
#   'rank': 'SPECIES',
#   'scientificName': 'Crypsis schoenoides (L.) Lam.',
#   'species': 'Crypsis schoenoides',
#   'speciesKey': 5290185,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5290185},
#  'Diaporthe phaseolorum': {'canonicalName': 'Diaporthe phaseolorum',
#   'class': 'Sordariomycetes',
#   'classKey': 320,
#   'confidence': 97,
#   'family': 'Diaporthaceae',
#   'familyKey': 4146,
#   'genus': 'Diaporthe',
#   'genusKey': 2566075,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Diaporthales',
#   'orderKey': 1289,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'SPECIES',
#   'scientificName': 'Diaporthe phaseolorum (Cooke & Ellis) Sacc., 1882',
#   'species': 'Diaporthe phaseolorum',
#   'speciesKey': 3444449,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3444449},
#  'Dinocheirus': {'canonicalName': 'Dinocheirus',
#   'class': 'Arachnida',
#   'classKey': 367,
#   'confidence': 93,
#   'family': 'Chernetidae',
#   'familyKey': 3691,
#   'genus': 'Dinocheirus',
#   'genusKey': 2127154,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Pseudoscorpiones',
#   'orderKey': 1161,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'GENUS',
#   'scientificName': 'Dinocheirus J. C. Chamberlin, 1929',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2127154},
#  'Euglena granulata': {'canonicalName': 'Euglena granulata',
#   'class': 'Euglenida',
#   'classKey': 200,
#   'confidence': 100,
#   'family': 'Euglenaceae',
#   'familyKey': 9158,
#   'genus': 'Euglena',
#   'genusKey': 3209628,
#   'kingdom': 'Protozoa',
#   'kingdomKey': 7,
#   'matchType': 'EXACT',
#   'order': 'Euglenales',
#   'orderKey': 1421,
#   'phylum': 'Euglenozoa',
#   'phylumKey': 41,
#   'rank': 'SPECIES',
#   'scientificName': 'Euglena granulata (G.A. Klebs) Schmitz',
#   'species': 'Euglena granulata',
#   'speciesKey': 3209820,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3209820},
#  'Formicinae': {'canonicalName': 'Formicidae',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 80,
#   'family': 'Formicidae',
#   'familyKey': 4342,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'FUZZY',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'FAMILY',
#   'scientificName': 'Formicidae Latreille, 1802',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4342},
#  'Furcula': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'Multiple equal matches for Furcula',
#   'synonym': False},
#  'Gymnodinium colymbeticum': {'canonicalName': 'Gymnodinium colymbeticum',
#   'class': 'Dinophyceae',
#   'classKey': 201,
#   'confidence': 100,
#   'family': 'Gymnodiniaceae',
#   'familyKey': 4971,
#   'genus': 'Gymnodinium',
#   'genusKey': 3207519,
#   'kingdom': 'Protozoa',
#   'kingdomKey': 7,
#   'matchType': 'EXACT',
#   'order': 'Gymnodiniales',
#   'orderKey': 684,
#   'phylum': 'Dinophyta',
#   'phylumKey': 109,
#   'rank': 'SPECIES',
#   'scientificName': 'Gymnodinium colymbeticum T.M. Harris',
#   'species': 'Gymnodinium colymbeticum',
#   'speciesKey': 3207619,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 3207619},
#  'Lestodiplosis affinis': {'canonicalName': 'Lestodiplosis affinis',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Cecidomyiidae',
#   'familyKey': 3338,
#   'genus': 'Lestodiplosis',
#   'genusKey': 1593713,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Lestodiplosis affinis Barnes, 1928',
#   'species': 'Lestodiplosis affinis',
#   'speciesKey': 1593757,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1593757},
#  'Listrognathus mactator': {'canonicalName': 'Listrognathus mactator',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Ichneumonidae',
#   'familyKey': 3512,
#   'genus': 'Listrognathus',
#   'genusKey': 1306649,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Hymenoptera',
#   'orderKey': 1457,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Listrognathus mactator (Thunberg, 1822)',
#   'species': 'Listrognathus mactator',
#   'speciesKey': 1306714,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 1306714},
#  'Lumbriculus variegatus': {'canonicalName': 'Lumbriculus variegatus',
#   'class': 'Clitellata',
#   'classKey': 255,
#   'confidence': 100,
#   'family': 'Lumbriculidae',
#   'familyKey': 6964,
#   'genus': 'Lumbriculus',
#   'genusKey': 2308018,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Lumbriculida',
#   'orderKey': 473,
#   'phylum': 'Annelida',
#   'phylumKey': 42,
#   'rank': 'SPECIES',
#   'scientificName': 'Lumbriculus variegatus (MĂźller, 1774)',
#   'species': 'Lumbriculus variegatus',
#   'speciesKey': 2308023,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2308023},
#  'Mycosphaerellaceae': {'canonicalName': 'Mycosphaerellaceae',
#   'class': 'Dothideomycetes',
#   'classKey': 183,
#   'confidence': 95,
#   'family': 'Mycosphaerellaceae',
#   'familyKey': 4797,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Capnodiales',
#   'orderKey': 1262,
#   'phylum': 'Ascomycota',
#   'phylumKey': 95,
#   'rank': 'FAMILY',
#   'scientificName': 'Mycosphaerellaceae Lindau',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4797},
#  'Noxius curtirostris': {'canonicalName': 'Noxius curtirostris',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Anthribidae',
#   'familyKey': 4206,
#   'genus': 'Noxius',
#   'genusKey': 1167403,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Coleoptera',
#   'orderKey': 1470,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Noxius curtirostris (Mulsant & Rey, 1861)',
#   'species': 'Noxius curtirostris',
#   'speciesKey': 4469442,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4469442},
#  'Odontophora': {'confidence': 99,
#   'matchType': 'NONE',
#   'note': 'Multiple equal matches for Odontophora',
#   'synonym': False},
#  'Olpidium gregarium': {'canonicalName': 'Olpidium gregarium',
#   'class': 'Chytridiomycetes',
#   'classKey': 318,
#   'confidence': 100,
#   'family': 'Olpidiaceae',
#   'familyKey': 1958,
#   'genus': 'Olpidium',
#   'genusKey': 2626967,
#   'kingdom': 'Fungi',
#   'kingdomKey': 5,
#   'matchType': 'EXACT',
#   'order': 'Chytridiales',
#   'orderKey': 1118,
#   'phylum': 'Chytridiomycota',
#   'phylumKey': 94,
#   'rank': 'SPECIES',
#   'scientificName': 'Olpidium gregarium (Nowak.) J. Schrรถt., 1886',
#   'species': 'Olpidium gregarium',
#   'speciesKey': 2626989,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2626989},
#  'Panicum clandestinum': {'canonicalName': 'Panicum clandestinum',
#   'class': 'Liliopsida',
#   'classKey': 196,
#   'confidence': 100,
#   'family': 'Poaceae',
#   'familyKey': 3073,
#   'genus': 'Panicum',
#   'genusKey': 2705064,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Poales',
#   'orderKey': 1369,
#   'phylum': 'Magnoliophyta',
#   'phylumKey': 49,
#   'rank': 'SPECIES',
#   'scientificName': 'Panicum clandestinum L.',
#   'species': 'Panicum clandestinum',
#   'speciesKey': 2702544,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 2702544},
#  'Paratanytarsus dissimilis': {'canonicalName': 'Paratanytarsus dissimilis',
#   'class': 'Insecta',
#   'classKey': 216,
#   'confidence': 100,
#   'family': 'Chironomidae',
#   'familyKey': 3343,
#   'genus': 'Paratanytarsus',
#   'genusKey': 1450500,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Diptera',
#   'orderKey': 811,
#   'phylum': 'Arthropoda',
#   'phylumKey': 54,
#   'rank': 'SPECIES',
#   'scientificName': 'Paratanytarsus dissimilis (Johannsen, 1905)',
#   'species': 'Paratanytarsus dissimilis',
#   'speciesKey': 4297556,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4297556},
#  'Periplomatidae': {'canonicalName': 'Periplomatidae',
#   'class': 'Bivalvia',
#   'classKey': 137,
#   'confidence': 96,
#   'family': 'Periplomatidae',
#   'familyKey': 6865,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Pholadomyoida',
#   'orderKey': 993,
#   'phylum': 'Mollusca',
#   'phylumKey': 52,
#   'rank': 'FAMILY',
#   'scientificName': 'Periplomatidae Dall, 1895',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 6865},
#  'Plectus tenuis': {'canonicalName': 'Plectus tenuis',
#   'class': 'Adenophorea',
#   'classKey': 251,
#   'confidence': 100,
#   'family': 'Plectidae',
#   'familyKey': 2607,
#   'genus': 'Plectus',
#   'genusKey': 2283075,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'order': 'Araeolaimida',
#   'orderKey': 978,
#   'phylum': 'Nematoda',
#   'phylumKey': 5967481,
#   'rank': 'SPECIES',
#   'scientificName': 'Plectus tenuis Bastian, 1865',
#   'species': 'Plectus tenuis',
#   'speciesKey': 5188562,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 5188562},
#  'Tragopogon pratensis L. subsp. orientalis': {'canonicalName': 'Tragopogon pratensis orientalis',
#   'class': 'Magnoliopsida',
#   'classKey': 220,
#   'confidence': 100,
#   'family': 'Asteraceae',
#   'familyKey': 3065,
#   'genus': 'Tragopogon',
#   'genusKey': 3092408,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Asterales',
#   'orderKey': 414,
#   'phylum': 'Magnoliophyta',
#   'phylumKey': 49,
#   'rank': 'SUBSPECIES',
#   'scientificName': 'Tragopogon pratensis subsp. orientalis (L.) Celak.',
#   'species': 'Tragopogon pratensis',
#   'speciesKey': 5386897,
#   'status': 'SYNONYM',
#   'synonym': True,
#   'usageKey': 5709399},
#  'Tritaphros retzii': {'canonicalName': 'Tritaphros retzii',
#   'class': 'Cestoda',
#   'classKey': 144,
#   'confidence': 100,
#   'family': 'Rhinobothriidae',
#   'familyKey': 6481842,
#   'genus': 'Tritaphros',
#   'genusKey': 4344888,
#   'kingdom': 'Animalia',
#   'kingdomKey': 1,
#   'matchType': 'EXACT',
#   'phylum': 'Platyhelminthes',
#   'phylumKey': 108,
#   'rank': 'SPECIES',
#   'scientificName': 'Tritaphros retzii Lรถnnberg, 1889',
#   'species': 'Tritaphros retzii',
#   'speciesKey': 4344889,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 4344889},
#  'Tryblionella scalaris': {'canonicalName': 'Tryblionella scalaris',
#   'class': 'Bacillariophyceae',
#   'classKey': 7071443,
#   'confidence': 100,
#   'family': 'Bacillariaceae',
#   'familyKey': 8716,
#   'genus': 'Tryblionella',
#   'genusKey': 2628076,
#   'kingdom': 'Plantae',
#   'kingdomKey': 6,
#   'matchType': 'EXACT',
#   'order': 'Bacillariales',
#   'orderKey': 1322,
#   'phylum': 'Bacillariophyta',
#   'phylumKey': 100,
#   'rank': 'SPECIES',
#   'scientificName': 'Tryblionella scalaris (Ehrenberg) Siver & P.B. Hamilton, 2005',
#   'species': 'Tryblionella scalaris',
#   'speciesKey': 6879455,
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'usageKey': 6879455}}

# %%
[test.fetch(client, name) for name in testcase]
# Out:
# [<coroutine object Collector.fetch at 0x7f1903bc3200>,
#  <coroutine object Collector.fetch at 0x7f1903bc3e60>,
#  <coroutine object Collector.fetch at 0x7f1903bc3048>,
#  <coroutine object Collector.fetch at 0x7f1903bc35c8>,
#  <coroutine object Collector.fetch at 0x7f1903bc3780>,
#  <coroutine object Collector.fetch at 0x7f1903bc3620>,
#  <coroutine object Collector.fetch at 0x7f1903bc3150>,
#  <coroutine object Collector.fetch at 0x7f191a5b8f68>,
#  <coroutine object Collector.fetch at 0x7f19022a49e8>,
#  <coroutine object Collector.fetch at 0x7f19022a4a98>,
#  <coroutine object Collector.fetch at 0x7f19022a41a8>,
#  <coroutine object Collector.fetch at 0x7f19022a48e0>,
#  <coroutine object Collector.fetch at 0x7f19022a4150>,
#  <coroutine object Collector.fetch at 0x7f19022a4360>,
#  <coroutine object Collector.fetch at 0x7f19022a4fc0>,
#  <coroutine object Collector.fetch at 0x7f19022a4af0>,
#  <coroutine object Collector.fetch at 0x7f19022a4d00>,
#  <coroutine object Collector.fetch at 0x7f19022a4eb8>,
#  <coroutine object Collector.fetch at 0x7f19022a4780>,
#  <coroutine object Collector.fetch at 0x7f19022a4938>,
#  <coroutine object Collector.fetch at 0x7f19022a40a0>,
#  <coroutine object Collector.fetch at 0x7f19022a4e08>,
#  <coroutine object Collector.fetch at 0x7f19022a4200>,
#  <coroutine object Collector.fetch at 0x7f19022a4258>,
#  <coroutine object Collector.fetch at 0x7f19022a4a40>,
#  <coroutine object Collector.fetch at 0x7f19022a40f8>,
#  <coroutine object Collector.fetch at 0x7f19022a45c8>,
#  <coroutine object Collector.fetch at 0x7f19022a4888>,
#  <coroutine object Collector.fetch at 0x7f19022a4468>,
#  <coroutine object Collector.fetch at 0x7f19022a4bf8>]

# %%
from time import time
from functools import wraps

# %%
def log_execution_time(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start = time()
        return_value = func(*args, **kwargs)
        message = "Executing {} took {:.03} seconds.".format(func.__name__,
                                                             time() - start)
        print(message)
        return return_value
    return wrapper

# %%
@log_execution_time
def circle(straal):
    return 3.14*straal**2

# %%
circle(10)
# Out:
# Executing circle took 4.05e-06 seconds.
# 314.0
