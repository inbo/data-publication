# %% [markdown]
# #**Aquatisch Beheer Conversie Coordinaten**

# %%
import numpy as np
import pandas as pd

# %%
survey_data = pd.read_csv("VermeerschOccIDRefine.csv")

# %%
survey_data.head()
# Out:
#   occurrrenceID eventDataControle  eventData  day  month  year   eventDate  \
# 0     INBO:AQ:1         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 1     INBO:AQ:2         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 2     INBO:AQ:3         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 3     INBO:AQ:4         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 4     INBO:AQ:5         2/09/2014  2/09/2014    2      9  2014  2014-09-02
#
#                 waterBody                 locality           X  \
# 0  Kanaal Brussel-Schelde     RO Grimbergen zone 2  152073.166
# 1  Kanaal Brussel-Schelde     RO Grimbergen zone 2  152073.166
# 2  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
# 3  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
# 4  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
#
#          ...                        scientificName2  \
# 0        ...         Abramis brama (Linnaeus, 1758)
# 1        ...         Abramis brama (Linnaeus, 1758)
# 2        ...         Abramis brama (Linnaeus, 1758)
# 3        ...         Abramis brama (Linnaeus, 1758)
# 4        ...         Abramis brama (Linnaeus, 1758)
#
#                    scientificName lifeStage  lenght weight individualCount  \
# 0  Abramis brama (Linnaeus, 1758)               222    NaN             1.0
# 1  Abramis brama (Linnaeus, 1758)               236    NaN             1.0
# 2  Abramis brama (Linnaeus, 1758)                83    NaN             1.0
# 3  Abramis brama (Linnaeus, 1758)                84    NaN             1.0
# 4  Abramis brama (Linnaeus, 1758)                85    NaN             2.0
#
#          dataSet samplingProtocol Mesohabitat           habitat
# 0  NTMBZeekanaal     schietfuiken        NTMB  afkalvende oever
# 1  NTMBZeekanaal     schietfuiken        NTMB  afkalvende oever
# 2  NTMBZeekanaal     schietfuiken        NTMB        breuksteen
# 3  NTMBZeekanaal     schietfuiken        NTMB        breuksteen
# 4  NTMBZeekanaal     schietfuiken        NTMB        breuksteen
#
# [5 rows x 24 columns]

# %%
import pyproj

# %%
lambert = pyproj.Proj("+init=EPSG:31370")
wgs84 = pyproj.Proj("+init=EPSG:4326")

# %%
pyproj.transform(lambert, wgs84,221651,44263)
# Out:
# (5.362054552936575, 49.70567727063289)

# %%
def transform_lambert_to_wgs(row):
    """
    Converts the x and y coordinates of this row into a Series of the
    longitude and latitude.
    
    """
    return pd.Series(pyproj.transform(lambert, wgs84, row['X'], row['Y']))

# %%
transform_lambert_to_wgs(survey_data.loc[0])
# Out:
# 0     4.398268
# 1    50.969082
# dtype: float64

# %%
survey_data.apply(transform_lambert_to_wgs, axis=1)
# Out:
#              0          1
# 0     4.398268  50.969082
# 1     4.398268  50.969082
# 2     4.400894  50.963693
# 3     4.400894  50.963693
# 4     4.400894  50.963693
# 5     4.400894  50.963693
# 6     4.400894  50.963693
# 7     4.400894  50.963693
# 8     4.399268  50.965768
# 9     4.396287  50.969536
# 10    4.396287  50.969536
# 11    4.301955  51.112028
# 12    4.396547  50.971186
# 13    4.302028  51.113571
# 14    4.301955  51.112028
# 15    4.396547  50.971186
# 16    4.396547  50.971186
# 17    4.396547  50.971186
# 18    4.396547  50.971186
# 19    4.396547  50.971186
# 20    4.396547  50.971186
# 21    4.399268  50.965768
# 22    4.305682  51.114920
# 23    4.301955  51.112028
# 24    4.302044  51.110879
# 25    4.395001  50.971297
# 26    4.305682  51.114920
# 27    4.301955  51.112028
# 28    4.301955  51.112028
# 29    4.264117  50.762639
# ...        ...        ...
# 3536  4.497324  51.023318
# 3537  4.497324  51.023318
# 3538  4.497324  51.023318
# 3539  4.497324  51.023318
# 3540  4.497324  51.023318
# 3541  4.497324  51.023318
# 3542  4.497324  51.023318
# 3543  4.497324  51.023318
# 3544  4.497324  51.023318
# 3545  4.497324  51.023318
# 3546  4.497324  51.023318
# 3547  4.497324  51.023318
# 3548  4.497324  51.023318
# 3549  4.497324  51.023318
# 3550  4.497324  51.023318
# 3551  4.497324  51.023318
# 3552  4.497324  51.023318
# 3553  4.497324  51.023318
# 3554  4.497324  51.023318
# 3555  4.497324  51.023318
# 3556  4.497324  51.023318
# 3557  4.497324  51.023318
# 3558  4.497324  51.023318
# 3559  4.497324  51.023318
# 3560  4.497324  51.023318
# 3561  4.497324  51.023318
# 3562  4.497324  51.023318
# 3563  4.497324  51.023318
# 3564  4.497324  51.023318
# 3565  4.497324  51.023318
#
# [3566 rows x 2 columns]

# %%
survey_data[["decimalLongitude" ,"decimalLatitude"]] = survey_data.apply(transform_lambert_to_wgs, axis=1)

# %%
survey_data.head()
# Out:
#   occurrrenceID eventDataControle  eventData  day  month  year   eventDate  \
# 0     INBO:AQ:1         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 1     INBO:AQ:2         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 2     INBO:AQ:3         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 3     INBO:AQ:4         2/09/2014  2/09/2014    2      9  2014  2014-09-02
# 4     INBO:AQ:5         2/09/2014  2/09/2014    2      9  2014  2014-09-02
#
#                 waterBody                 locality           X  \
# 0  Kanaal Brussel-Schelde     RO Grimbergen zone 2  152073.166
# 1  Kanaal Brussel-Schelde     RO Grimbergen zone 2  152073.166
# 2  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
# 3  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
# 4  Kanaal Brussel-Schelde  LO Grimbergen zone 4b_B  152257.821
#
#         ...         lifeStage lenght weight  individualCount        dataSet  \
# 0       ...                      222    NaN              1.0  NTMBZeekanaal
# 1       ...                      236    NaN              1.0  NTMBZeekanaal
# 2       ...                       83    NaN              1.0  NTMBZeekanaal
# 3       ...                       84    NaN              1.0  NTMBZeekanaal
# 4       ...                       85    NaN              2.0  NTMBZeekanaal
#
#   samplingProtocol Mesohabitat           habitat decimalLongitude  \
# 0     schietfuiken        NTMB  afkalvende oever         4.398268
# 1     schietfuiken        NTMB  afkalvende oever         4.398268
# 2     schietfuiken        NTMB        breuksteen         4.400894
# 3     schietfuiken        NTMB        breuksteen         4.400894
# 4     schietfuiken        NTMB        breuksteen         4.400894
#
#    decimalLatitude
# 0        50.969082
# 1        50.969082
# 2        50.963693
# 3        50.963693
# 4        50.963693
#
# [5 rows x 26 columns]

# %%
survey_data.to_csv("Vermeersch_completed.csv", index=False)

# %%
import matplotlib.pyplot as plt

# %%
from pylab import *

# %%
import folium as fol

# %%
map_1 = fol.Map(location=[50.372, 5.6972],
                   zoom_start=8,
                   tiles='Stamen Terrain')
for ids, row in survey_data.loc[:100,:].iterrows():
    fol.Marker(row[['decimalLatitude', 'decimalLongitude']], popup=row["scientificName"]).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
