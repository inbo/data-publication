# %% [markdown]
# **Species name extraction**

# %%
import json
import requests

import pandas as pd

# %%
from gbif_species_name_match import (extract_gbif_species_names_info, 
                                     extract_species_information,
                                     extract_gbif_accepted_key)

# %%
redListunVal = pd.read_csv ("NonValidatedRedListsExploratory.csv")

# %%
redListunVal.head()
# Out:
#                      UniqueID TaxonomicGroup  YearPublished   Kingdom  \
# 0   INBO:RL:NONVAL:AMP:1996:1     Amphibians           1996  Animalia
# 1  INBO:RL:NONVAL:AMP:1996:10     Amphibians           1996  Animalia
# 2  INBO:RL:NONVAL:AMP:1996:11     Amphibians           1996  Animalia
# 3  INBO:RL:NONVAL:AMP:1996:12     Amphibians           1996  Animalia
# 4  INBO:RL:NONVAL:AMP:1996:13     Amphibians           1996  Animalia
#
#           scientificName        vernacularname           RLCAsPublished RLC  \
# 0    Alytes obstetricans       Vroedmeesterpad                 Bedreigd  EN
# 1  Salamandra salamandra        Vuursalamander                Kwetsbaar  VU
# 2     Triturus alpestris  Alpenwatersalamander  Momenteel niet bedreigd  LC
# 3     Triturus cristatus         Kamsalamander                 Zeldzaam  NT
# 4    Triturus helveticus     Vinpootsalamander                 Zeldzaam  NT
#
#   RLCEurope  Criteria          Reference  \
# 0        LC  Regional  BauwensClaus_1996
# ...

# %%
updated_tsv = extract_species_information("NonValidatedRedListsExploratory.csv", 
                                          output=None,                              
                                          api_terms=["usageKey", 
                                                     "scientificName", 
                                                     "canonicalName",
                                                     "status", 
                                                     "rank", 
                                                     "matchType", 
                                                     "confidence"],
                                         )
# Out:
# Using columns scientificName and Kingdom for API request.

# %%
unvalidatedList = extract_species_information("NonValidatedRedListsExploratory.csv", output=None, api_terms="all")
# Out:
# Using columns scientificName and Kingdom for API request.

# %%
updated_tsv.head()
# Out:
#                      UniqueID TaxonomicGroup YearPublished   Kingdom  \
# 0   INBO:RL:NONVAL:AMP:1996:1     Amphibians          1996  Animalia
# 1  INBO:RL:NONVAL:AMP:1996:10     Amphibians          1996  Animalia
# 2  INBO:RL:NONVAL:AMP:1996:11     Amphibians          1996  Animalia
# 3  INBO:RL:NONVAL:AMP:1996:12     Amphibians          1996  Animalia
# 4  INBO:RL:NONVAL:AMP:1996:13     Amphibians          1996  Animalia
#
#           scientificName        vernacularname           RLCAsPublished RLC  \
# 0    Alytes obstetricans       Vroedmeesterpad                 Bedreigd  EN
# 1  Salamandra salamandra        Vuursalamander                Kwetsbaar  VU
# 2     Triturus alpestris  Alpenwatersalamander  Momenteel niet bedreigd  LC
# 3     Triturus cristatus         Kamsalamander                 Zeldzaam  NT
# 4    Triturus helveticus     Vinpootsalamander                 Zeldzaam  NT
#
#   RLCEurope  Criteria                     ...                      \
# ...

# %%
unvalidatedList.head()
# Out:
#                      UniqueID TaxonomicGroup YearPublished   Kingdom  \
# 0   INBO:RL:NONVAL:AMP:1996:1     Amphibians          1996  Animalia
# 1  INBO:RL:NONVAL:AMP:1996:10     Amphibians          1996  Animalia
# 2  INBO:RL:NONVAL:AMP:1996:11     Amphibians          1996  Animalia
# 3  INBO:RL:NONVAL:AMP:1996:12     Amphibians          1996  Animalia
# 4  INBO:RL:NONVAL:AMP:1996:13     Amphibians          1996  Animalia
#
#           scientificName        vernacularname           RLCAsPublished RLC  \
# 0    Alytes obstetricans       Vroedmeesterpad                 Bedreigd  EN
# 1  Salamandra salamandra        Vuursalamander                Kwetsbaar  VU
# 2     Triturus alpestris  Alpenwatersalamander  Momenteel niet bedreigd  LC
# 3     Triturus cristatus         Kamsalamander                 Zeldzaam  NT
# 4    Triturus helveticus     Vinpootsalamander                 Zeldzaam  NT
#
#   RLCEurope  Criteria       ...        gbifapi_orderKey gbifapi_phylum  \
# ...

# %%
validatedList.to_csv("unvalidatedRedListDwCNotebookOutput.csv", index=False)
